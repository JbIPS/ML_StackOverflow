# %%
import pandas as pd
import re
import nltk
from nltk.stem import WordNetLemmatizer
import numpy as np
import matplotlib.pyplot as plt
from kneed import KneeLocator

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/jbrichardet/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/jbrichardet/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/jbrichardet/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/jbrichardet/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# # Import des données

# %%
dataset = pd.read_csv('dataset.csv')[['Body', 'Tags']]
dataset
# Out:
#                                                     Body  \
# 0      <p>I have a UIImageView that I have already se...
# 1      <blockquote>\n  <p><strong>Possible Duplicate:...
# 2      <h2>The requirements I'm up against</h2>\n\n<p...
# 3      <p>I keep getting the following error "Could n...
# 4      <p>I am using the xml-simple gem inside a rake...
# ...                                                  ...
# 99707  <p>Is it possible to have a singleton in a fac...
# 99708  <p>I was wondering if there is some option to ...
# 99709  <p>I have found the "Getting Started" document...
# 99710  <p>I have a 2D area with "dots" distributed on...
# 99711  <p>For a stylesheet I'm writing (actually for ...
#
#                                                     Tags
# 0                         <iphone><uiimageview><uiimage>
# 1                             <delphi><file-permissions>
# 2                                         <c#><winforms>
# 3                   <wcf><https><transport><credentials>
# 4                                <ruby><xml><xml-simple>
# ...                                                  ...
# 99707                                             <java>
# 99708  <c#><visual-studio-2008><resharper><using-dire...
# 99709                                    <iphone><xcode>
# 99710     <algorithm><data-structures><image-processing>
# 99711                                             <xslt>
#
# [99712 rows x 2 columns]

# %% [markdown]
# # Suppression des tags les moins communs

# %%
dataset['Tags'] = dataset['Tags'].str.split(r'<(.+?)>').apply(lambda x: [tag for tag in x if tag != ''])

# %%
tagsFreq = dataset['Tags'].to_frame().apply(lambda x : pd.Series([x['Tags'], nltk.FreqDist(x['Tags'])], index=['tokens', 'frequency']), axis=1, result_type='expand')

# %%
total_freq = {}
for dictionnary in tagsFreq['frequency']:
    for k,v in dictionnary.items():
        if k in total_freq:
            total_freq[k] += v
        else:
            total_freq[k] = v

freq_list = sorted(total_freq.items(), key=lambda x: x[1], reverse=True)
freq_list
# Out:
# [('c#', 11112),
#  ('java', 7667),
#  ('.net', 6707),
#  ('javascript', 6300),
#  ('php', 5567),
#  ('c++', 4964),
#  ('asp.net', 4824),
#  ('python', 4671),
#  ('jquery', 3406),
#  ('html', 3278),
#  ('sql', 3174),
#  ('sql-server', 2610),
#  ('mysql', 2528),
#  ('android', 2433),
#  ('iphone', 2372),
#  ('css', 2162),
#  ('c', 2065),
#  ('windows', 1880),
#  ('ruby-on-rails', 1706),
#  ('database', 1619),
#  ('visual-studio', 1492),
#  ('xml', 1482),
#  ('ruby', 1471),
#  ('wpf', 1370),
#  ('asp.net-mvc', 1370),
#  ('objective-c', 1317),
#  ('vb.net', 1214),
#  ('winforms', 1200),
#  ('linux', 1198),
#  ('regex', 1183),
#  ('performance', 1086),
#  ('ajax', 1041),
#  ('arrays', 984),
#  ('visual-studio-2008', 916),
#  ('multithreading', 914),
#  ('oracle', 897),
#  ('django', 883),
#  ('algorithm', 879),
#  ('string', 878),
#  ('svn', 856),
#  ('web-services', 852),
#  ('unit-testing', 820),
#  ('security', 801),
#  ('linq', 801),
#  ('ios', 772),
#  ('eclipse', 752),
#  ('macos', 724),
#  ('user-interface', 711),
#  ('excel', 702),
#  ('winapi', 697),
#  ('perl', 695),
#  ('sql-server-2005', 691),
#  ('json', 665),
#  ('debugging', 660),
#  ('oop', 660),
#  ('apache-flex', 658),
#  ('language-agnostic', 653),
#  ('delphi', 649),
#  ('flash', 631),
#  ('wcf', 621),
#  ('tsql', 585),
#  ('apache', 574),
#  ('sharepoint', 568),
#  ('version-control', 560),
#  ('image', 550),
#  ('actionscript-3', 539),
#  ('vba', 539),
#  ('silverlight', 534),
#  ('file', 527),
#  ('cocoa', 502),
#  ('cocoa-touch', 494),
#  ('design-patterns', 489),
#  ('iis', 485),
#  ('r', 477),
#  ('git', 474),
#  ('linq-to-sql', 474),
#  ('spring', 465),
#  ('internet-explorer', 459),
#  ('testing', 454),
#  ('http', 453),
#  ('validation', 452),
#  ('exception', 451),
#  ('xcode', 447),
#  ('ms-access', 440),
#  ('forms', 436),
#  ('bash', 436),
#  ('generics', 436),
#  ('hibernate', 427),
#  ('events', 423),
#  ('shell', 415),
#  ('parsing', 409),
#  ('optimization', 407),
#  ('postgresql', 404),
#  ('email', 388),
#  ('unix', 388),
#  ('list', 382),
#  ('node.js', 379),
#  ('web-applications', 373),
#  ('database-design', 372),
#  ('.net-3.5', 369),
#  ('swing', 365),
#  ('networking', 365),
#  ('wordpress', 362),
#  ('datetime', 360),
#  ('deployment', 358),
#  ('installation', 355),
#  ('visual-c++', 353),
#  ('entity-framework', 352),
#  ('jsp', 352),
#  ('caching', 348),
#  ('nhibernate', 346),
#  ('logging', 339),
#  ('templates', 338),
#  ('stored-procedures', 337),
#  ('qt', 329),
#  ('firefox', 327),
#  ('reflection', 325),
#  ('scripting', 324),
#  ('math', 323),
#  ('function', 319),
#  ('authentication', 318),
#  ('data-binding', 317),
#  ('class', 314),
#  ('api', 312),
#  ('xslt', 311),
#  ('visual-studio-2010', 308),
#  ('rest', 306),
#  ('browser', 306),
#  ('sockets', 305),
#  ('sorting', 298),
#  ('reactjs', 297),
#  ('session', 296),
#  ('sqlite', 295),
#  ('serialization', 295),
#  ('command-line', 294),
#  ('architecture', 292),
#  ('python-3.x', 291),
#  ('memory', 290),
#  ('inheritance', 289),
#  ('swift', 286),
#  ('angularjs', 286),
#  ('date', 285),
#  ('visual-studio-2005', 283),
#  ('search', 280),
#  ('reporting-services', 280),
#  ('xaml', 279),
#  ('sql-server-2008', 278),
#  ('.net-2.0', 274),
#  ('mfc', 273),
#  ('facebook', 272),
#  ('com', 271),
#  ('dom', 269),
#  ('model-view-controller', 267),
#  ('vb6', 267),
#  ('coding-style', 264),
#  ('tomcat', 263),
#  ('ide', 262),
#  ('vim', 261),
#  ('url', 260),
#  ('asp-classic', 259),
#  ('unicode', 259),
#  ('google-app-engine', 259),
#  ('configuration', 256),
#  ('encryption', 255),
#  ('data-structures', 253),
#  ('jakarta-ee', 251),
#  ('stl', 250),
#  ('orm', 246),
#  ('ssl', 239),
#  ('gcc', 239),
#  ('audio', 236),
#  ('powershell', 235),
#  ('collections', 235),
#  ('pdf', 235),
#  ('batch-file', 234),
#  ('emacs', 233),
#  ('graphics', 231),
#  ('memory-management', 231),
#  ('drupal', 230),
#  ('dll', 230),
#  ('codeigniter', 226),
#  ('angular', 223),
#  ('listview', 223),
#  ('windows-vista', 222),
#  ('plugins', 220),
#  ('ipad', 219),
#  ('tfs', 219),
#  ('soap', 219),
#  ('matlab', 217),
#  ('jsf', 215),
#  ('.htaccess', 214),
#  ('controls', 213),
#  ('google-maps', 212),
#  ('csv', 211),
#  ('file-io', 211),
#  ('pointers', 210),
#  ('opengl', 209),
#  ('compiler-construction', 209),
#  ('loops', 208),
#  ('variables', 206),
#  ('mongodb', 205),
#  ('windows-mobile', 205),
#  ('scala', 202),
#  ('laravel', 202),
#  ('vbscript', 201),
#  ('syntax', 201),
#  ('ado.net', 201),
#  ('frameworks', 196),
#  ('maven-2', 195),
#  ('process', 194),
#  ('ubuntu', 192),
#  ('encoding', 192),
#  ('msbuild', 190),
#  ('interface', 190),
#  ('types', 188),
#  ('user-controls', 188),
#  ('object', 188),
#  ('gridview', 187),
#  ('actionscript', 186),
#  ('dictionary', 186),
#  ('google-chrome', 185),
#  ('uitableview', 185),
#  ('jquery-ui', 184),
#  ('concurrency', 182),
#  ('refactoring', 181),
#  ('cookies', 180),
#  ('ant', 178),
#  ('open-source', 177),
#  ('printing', 175),
#  ('functional-programming', 175),
#  ('jpa', 174),
#  ('video', 173),
#  ('jdbc', 173),
#  ('tdd', 173),
#  ('pandas', 172),
#  ('asp.net-ajax', 172),
#  ('hash', 172),
#  ('indexing', 172),
#  ('xsd', 171),
#  ('mod-rewrite', 171),
#  ('asp.net-mvc-2', 171),
#  ('boost', 171),
#  ('xpath', 170),
#  ('servlets', 170),
#  ('random', 168),
#  ('64-bit', 168),
#  ('xhtml', 167),
#  ('zend-framework', 166),
#  ('ms-word', 166),
#  ('internationalization', 165),
#  ('active-directory', 165),
#  ('interop', 165),
#  ('activerecord', 165),
#  ('image-processing', 165),
#  ('haskell', 164),
#  ('assembly', 164),
#  ('automation', 162),
#  ('layout', 161),
#  ('project-management', 160),
#  ('windows-xp', 158),
#  ('filesystems', 158),
#  ('memory-leaks', 156),
#  ('selenium', 156),
#  ('time', 156),
#  ('transactions', 156),
#  ('grails', 155),
#  ('netbeans', 154),
#  ('build-process', 154),
#  ('embedded', 154),
#  ('redirect', 153),
#  ('error-handling', 152),
#  ('mobile', 152),
#  ('text', 151),
#  ('post', 151),
#  ('reference', 151),
#  ('iframe', 151),
#  ('outlook', 149),
#  ('formatting', 149),
#  ('asynchronous', 149),
#  ('gwt', 149),
#  ('join', 149),
#  ('enums', 148),
#  ('lambda', 147),
#  ('permissions', 146),
#  ('dynamic', 146),
#  ('editor', 146),
#  ('utf-8', 145),
#  ('amazon-web-services', 144),
#  ('compact-framework', 144),
#  ('binding', 144),
#  ('cakephp', 143),
#  ('webforms', 143),
#  ('f#', 143),
#  ('crystal-reports', 142),
#  ('mocking', 142),
#  ('animation', 141),
#  ('windows-installer', 140),
#  ('datagridview', 140),
#  ('tcp', 139),
#  ('casting', 139),
#  ('groovy', 139),
#  ('directory', 137),
#  ('plsql', 137),
#  ('iis-7', 136),
#  ('namespaces', 136),
#  ('recursion', 136),
#  ('ftp', 136),
#  ('build', 135),
#  ('build-automation', 134),
#  ('merge', 134),
#  ('https', 133),
#  ('localization', 133),
#  ('methods', 133),
#  ('ios4', 133),
#  ('core-data', 131),
#  ('fonts', 131),
#  ('cross-browser', 129),
#  ('garbage-collection', 129),
#  ('exception-handling', 129),
#  ('windows-services', 129),
#  ('makefile', 128),
#  ('properties', 128),
#  ('tortoisesvn', 128),
#  ('spring-mvc', 127),
#  ('django-models', 127),
#  ('service', 127),
#  ('azure', 125),
#  ('coldfusion', 125),
#  ('resources', 125),
#  ('ssis', 124),
#  ('programming-languages', 123),
#  ('cross-platform', 123),
#  ('linker', 123),
#  ('dns', 122),
#  ('operating-system', 122),
#  ('locking', 122),
#  ('button', 122),
#  ('typescript', 121),
#  ('assemblies', 121),
#  ('proxy', 121),
#  ('iis-6', 121),
#  ('firebase', 120),
#  ('file-upload', 120),
#  ('select', 120),
#  ('textbox', 120),
#  ('colors', 120),
#  ('dependency-injection', 119),
#  ('passwords', 119),
#  ('rss', 119),
#  ('numpy', 118),
#  ('profiling', 118),
#  ('routing', 118),
#  ('parameters', 118),
#  ('safari', 116),
#  ('continuous-integration', 116),
#  ('air', 116),
#  ('import', 116),
#  ('path', 115),
#  ('moss', 115),
#  ('constructor', 115),
#  ('junit', 115),
#  ('jboss', 115),
#  ('console', 115),
#  ('ssh', 114),
#  ('if-statement', 114),
#  ('header', 114),
#  ('floating-point', 114),
#  ('module', 112),
#  ('compression', 112),
#  ('c#-3.0', 112),
#  ('curl', 111),
#  ('delegates', 111),
#  ('migration', 111),
#  ('lisp', 110),
#  ('sql-server-2000', 110),
#  ('triggers', 109),
#  ('mercurial', 109),
#  ('full-text-search', 108),
#  ('mvvm', 108),
#  ('static', 108),
#  ('upload', 107),
#  ('python-2.7', 107),
#  ('dataframe', 106),
#  ('null', 106),
#  ('.net-4.0', 106),
#  ('macros', 105),
#  ('compilation', 105),
#  ('backup', 104),
#  ('datagrid', 104),
#  ('input', 104),
#  ('svg', 103),
#  ('synchronization', 103),
#  ('cryptography', 103),
#  ('naming-conventions', 103),
#  ('charts', 102),
#  ('vector', 102),
#  ('dependencies', 102),
#  ('timer', 102),
#  ('keyboard-shortcuts', 102),
#  ('nunit', 102),
#  ('internet-explorer-7', 102),
#  ('menu', 101),
#  ('tags', 101),
#  ('registry', 101),
#  ('hyperlink', 101),
#  ('flutter', 100),
#  ('keyboard', 100),
#  ('jar', 100),
#  ('c#-4.0', 100),
#  ('twitter-bootstrap', 99),
#  ('for-loop', 99),
#  ('checkbox', 99),
#  ('blackberry', 99),
#  ('download', 99),
#  ('event-handling', 98),
#  ('attributes', 98),
#  ('mono', 98),
#  ('dataset', 98),
#  ('internet-explorer-6', 98),
#  ('geometry', 97),
#  ('combobox', 97),
#  ('documentation', 97),
#  ('smtp', 97),
#  ('webserver', 96),
#  ('io', 95),
#  ('opencv', 95),
#  ('java-me', 95),
#  ('iterator', 95),
#  ('cmd', 94),
#  ('autocomplete', 94),
#  ('web-config', 94),
#  ('drop-down-menu', 94),
#  ('agile', 94),
#  ('spring-boot', 93),
#  ('workflow', 93),
#  ('comparison', 93),
#  ('login', 93),
#  ('struct', 93),
#  ('3d', 93),
#  ('scope', 91),
#  ('scroll', 91),
#  ('binary', 91),
#  ('magento', 91),
#  ('schema', 91),
#  ('twitter', 91),
#  ('eclipse-plugin', 91),
#  ('datatable', 90),
#  ('inversion-of-control', 90),
#  ('statistics', 90),
#  ('ms-office', 90),
#  ('resharper', 90),
#  ('opengl-es', 90),
#  ('stream', 90),
#  ('character-encoding', 89),
#  ('graph', 89),
#  ('replace', 89),
#  ('odbc', 89),
#  ('cvs', 89),
#  ('cruisecontrol.net', 88),
#  ('html-table', 88),
#  ('clr', 88),
#  ('extjs', 88),
#  ('web', 87),
#  ('listbox', 87),
#  ('activex', 87),
#  ('include', 87),
#  ('lucene', 87),
#  ('code-generation', 86),
#  ('drag-and-drop', 86),
#  ('openid', 86),
#  ('calendar', 86),
#  ('struts', 86),
#  ('treeview', 86),
#  ('diff', 85),
#  ('android-studio', 85),
#  ('url-rewriting', 85),
#  ('rubygems', 84),
#  ('c++11', 84),
#  ('model', 84),
#  ('network-programming', 84),
#  ('latex', 84),
#  ('wsdl', 84),
#  ('ruby-on-rails-3', 84),
#  ('monitoring', 84),
#  ('http-headers', 84),
#  ('xml-serialization', 84),
#  ('automated-tests', 84),
#  ('drupal-6', 83),
#  ('insert', 83),
#  ('react-native', 82),
#  ('icons', 82),
#  ('components', 82),
#  ('docker', 81),
#  ('multidimensional-array', 81),
#  ('constants', 81),
#  ('seo', 81),
#  ('canvas', 81),
#  ('timeout', 80),
#  ('crash', 79),
#  ('sed', 79),
#  ('reporting', 79),
#  ('integer', 79),
#  ('annotations', 78),
#  ('clojure', 78),
#  ('c-preprocessor', 78),
#  ('directx', 78),
#  ('windows-server-2003', 78),
#  ('vue.js', 77),
#  ('nant', 77),
#  ('terminal', 77),
#  ('linq-to-entities', 77),
#  ('report', 77),
#  ('timezone', 76),
#  ('callback', 76),
#  ('c++-cli', 76),
#  ('jvm', 76),
#  ('lua', 76),
#  ('hadoop', 75),
#  ('versioning', 75),
#  ('content-management-system', 75),
#  ('iphone-sdk-3.0', 75),
#  ('view', 75),
#  ('awk', 75),
#  ('prototypejs', 75),
#  ('gdb', 75),
#  ('remoting', 74),
#  ('singleton', 74),
#  ('hosting', 74),
#  ('jquery-plugins', 74),
#  ('resize', 74),
#  ('pagination', 73),
#  ('foreach', 73),
#  ('replication', 73),
#  ('applet', 73),
#  ('copy', 73),
#  ('joomla', 73),
#  ('comments', 73),
#  ('vmware', 73),
#  ('tkinter', 72),
#  ('express', 72),
#  ('db2', 72),
#  ('filter', 72),
#  ('background', 72),
#  ('symfony', 72),
#  ('hardware', 72),
#  ('jquery-selectors', 72),
#  ('x86', 72),
#  ('tree', 72),
#  ('export', 71),
#  ('parallel-processing', 71),
#  ('android-activity', 71),
#  ('navigation', 71),
#  ('cygwin', 71),
#  ('extension-methods', 71),
#  ('wix', 71),
#  ('ldap', 71),
#  ('usability', 71),
#  ('cordova', 70),
#  ('intellij-idea', 70),
#  ('matrix', 70),
#  ('clickonce', 70),
#  ('scheme', 70),
#  ('windows-server-2008', 70),
#  ('nlp', 70),
#  ('asp.net-2.0', 70),
#  ('linq-to-xml', 70),
#  ('struts2', 69),
#  ('sharepoint-2007', 69),
#  ('split', 69),
#  ('erlang', 68),
#  ('windows-7', 68),
#  ('dialog', 68),
#  ('modal-dialog', 68),
#  ('tabs', 68),
#  ('unity3d', 67),
#  ('focus', 67),
#  ('master-pages', 67),
#  ('terminology', 67),
#  ('bit-manipulation', 67),
#  ('initialization', 66),
#  ('wmi', 66),
#  ('format', 66),
#  ('maven', 66),
#  ('dojo', 66),
#  ('gdi+', 66),
#  ('visual-sourcesafe', 66),
#  ('sdk', 65),
#  ('go', 65),
#  ('virtualization', 65),
#  ('count', 65),
#  ('github', 65),
#  ('nginx', 65),
#  ('controller', 65),
#  ('memcached', 65),
#  ('mapping', 65),
#  ('usb', 65),
#  ('xss', 65),
#  ('metaprogramming', 65),
#  ('branch', 65),
#  ('viewstate', 65),
#  ('javafx', 64),
#  ('escaping', 64),
#  ('log4net', 64),
#  ('mouse', 64),
#  ('xna', 64),
#  ('adobe', 63),
#  ('set', 63),
#  ('zip', 63),
#  ('uml', 63),
#  ('closures', 62),
#  ('interface-builder', 62),
#  ('matplotlib', 62),
#  ('mysqli', 62),
#  ('xmlhttprequest', 62),
#  ('silverlight-4.0', 62),
#  ('gtk', 62),
#  ('licensing', 62),
#  ('kernel', 62),
#  ('serial-port', 62),
#  ('solaris', 62),
#  ('uiview', 61),
#  ('machine-learning', 61),
#  ('hex', 61),
#  ('repository', 61),
#  ('amazon-s3', 61),
#  ('vsto', 61),
#  ('settings', 61),
#  ('wxpython', 60),
#  ('code-coverage', 60),
#  ('webkit', 60),
#  ('heroku', 60),
#  ('bitmap', 60),
#  ('css-selectors', 60),
#  ('development-environment', 60),
#  ('domain-driven-design', 60),
#  ('streaming', 60),
#  ('cgi', 60),
#  ('scrum', 60),
#  ('theory', 60),
#  ('geolocation', 59),
#  ('kotlin', 59),
#  ('cron', 59),
#  ('foreign-keys', 59),
#  ('perforce', 59),
#  ('castle-windsor', 59),
#  ('png', 59),
#  ('certificate', 59),
#  ('apache2', 59),
#  ('silverlight-2.0', 59),
#  ('dart', 58),
#  ('tensorflow', 58),
#  ('numbers', 58),
#  ('polymorphism', 58),
#  ('sharepoint-2010', 58),
#  ('ffmpeg', 58),
#  ('warnings', 58),
#  ('compiler-errors', 58),
#  ('udp', 58),
#  ('routes', 58),
#  ('websphere', 58),
#  ('pdo', 57),
#  ('nosql', 57),
#  ('queue', 57),
#  ('client', 57),
#  ('apache-spark', 56),
#  ('rspec', 56),
#  ('connection', 56),
#  ('sms', 56),
#  ('stack', 56),
#  ('amazon-ec2', 56),
#  ('django-admin', 56),
#  ('asp.net-membership', 56),
#  ('hook', 56),
#  ('integration', 56),
#  ('widget', 55),
#  ('sysadmin', 55),
#  ('arraylist', 55),
#  ('postback', 55),
#  ('symfony1', 55),
#  ('environment-variables', 55),
#  ('runtime', 55),
#  ('scalability', 55),
#  ('views', 55),
#  ('window', 55),
#  ('mp3', 55),
#  ('ssms', 54),
#  ('connection-string', 54),
#  ('openssl', 54),
#  ('exchange-server', 54),
#  ('persistence', 54),
#  ('boolean', 54),
#  ('oracle10g', 54),
#  ('log4j', 54),
#  ('get', 54),
#  ('popup', 54),
#  ('text-editor', 54),
#  ('standards', 54),
#  ('computer-science', 54),
#  ('language-features', 53),
#  ('drawing', 53),
#  ('doctrine', 53),
#  ('jython', 53),
#  ('uiviewcontroller', 53),
#  ('text-files', 53),
#  ('command', 53),
#  ('biztalk', 53),
#  ('themes', 52),
#  ('grep', 52),
#  ('windows-ce', 52),
#  ('compatibility', 52),
#  ('entity-framework-4', 52),
#  ('solr', 52),
#  ('sql-injection', 52),
#  ('add-in', 52),
#  ('switch-statement', 52),
#  ('yui', 52),
#  ('web-crawler', 51),
#  ('mstest', 51),
#  ('spring-security', 51),
#  ('java-native-interface', 51),
#  ('debian', 51),
#  ('map', 51),
#  ('nested', 51),
#  ('plot', 51),
#  ('aop', 51),
#  ('internet-explorer-8', 51),
#  ('pinvoke', 51),
#  ('grid', 51),
#  ('gmail', 51),
#  ('type-conversion', 51),
#  ('metadata', 50),
#  ('wiki', 50),
#  ('jstl', 50),
#  ('constraints', 50),
#  ('facebook-graph-api', 50),
#  ('graph-theory', 50),
#  ('data-access-layer', 50),
#  ('desktop', 50),
#  ('linked-list', 49),
#  ('ggplot2', 49),
#  ('asp.net-mvc-4', 49),
#  ('jaxb', 49),
#  ('applescript', 49),
#  ('asp.net-core', 49),
#  ('dom-events', 49),
#  ('obfuscation', 49),
#  ('group-by', 49),
#  ('google-maps-api-3', 49),
#  ('find', 49),
#  ('asmx', 49),
#  ('web-parts', 49),
#  ('ado', 49),
#  ('arguments', 49),
#  ('code-analysis', 49),
#  ('syntax-highlighting', 49),
#  ('updatepanel', 49),
#  ('ipc', 49),
#  ('workflow-foundation', 48),
#  ('label', 48),
#  ('intellisense', 48),
#  ('notifications', 48),
#  ('javascript-events', 48),
#  ('httpwebrequest', 48),
#  ('android-intent', 48),
#  ('artificial-intelligence', 48),
#  ('informix', 48),
#  ('flex4', 48),
#  ('timestamp', 48),
#  ('android-fragments', 47),
#  ('hashtable', 47),
#  ('compare', 47),
#  ('malloc', 47),
#  ('styles', 47),
#  ('many-to-many', 47),
#  ('fluent-nhibernate', 47),
#  ('textarea', 47),
#  ('field', 47),
#  ('ip-address', 47),
#  ('classpath', 47),
#  ('class-design', 47),
#  ('oledb', 47),
#  ('delphi-2009', 47),
#  ('version', 46),
#  ('jms', 46),
#  ('jqgrid', 46),
#  ('django-templates', 46),
#  ('configuration-files', 46),
#  ('web-scraping', 46),
#  ('image-manipulation', 46),
#  ('hudson', 46),
#  ('printf', 46),
#  ('operators', 46),
#  ('pipe', 46),
#  ('newline', 46),
#  ('2d', 46),
#  ('dvcs', 45),
#  ('glassfish', 45),
#  ('messaging', 45),
#  ('oauth', 45),
#  ('forms-authentication', 45),
#  ('gps', 45),
#  ('reportviewer', 45),
#  ('integration-testing', 44),
#  ('rdbms', 44),
#  ('bug-tracking', 44),
#  ('iteration', 44),
#  ('tooltip', 44),
#  ('core-animation', 44),
#  ('concatenation', 44),
#  ('linux-kernel', 44),
#  ('mongoose', 44),
#  ('accessibility', 44),
#  ('operator-overloading', 44),
#  ('ejb', 44),
#  ('ascii', 44),
#  ('char', 44),
#  ('qt4', 44),
#  ('gac', 44),
#  ('msmq', 44),
#  ('while-loop', 43),
#  ('javadoc', 43),
#  ('firebug', 43),
#  ('windows-phone-7', 43),
#  ('distributed', 43),
#  ('cloud', 43),
#  ('cross-domain', 43),
#  ('common-lisp', 43),
#  ('storage', 43),
#  ('html-select', 43),
#  ('paypal', 43),
#  ('google-analytics', 43),
#  ('actionscript-2', 43),
#  ('system', 43),
#  ('screen-scraping', 43),
#  ('mvp', 43),
#  ('sql-server-ce', 43),
#  ('vi', 43),
#  ('enterprise-library', 43),
#  ('guid', 43),
#  ('gradle', 42),
#  ('android-layout', 42),
#  ('sqlalchemy', 42),
#  ('d3.js', 42),
#  ('asp.net-web-api', 42),
#  ('cuda', 42),
#  ('uiscrollview', 42),
#  ('sql-update', 42),
#  ('hashmap', 42),
#  ('uikit', 42),
#  ('segmentation-fault', 42),
#  ('thread-safety', 42),
#  ('mxml', 42),
#  ('localhost', 42),
#  ('client-server', 42),
#  ('dotnetnuke', 42),
#  ('naming', 42),
#  ('seam', 42),
#  ('key', 42),
#  ('rendering', 42),
#  ('gis', 42),
#  ('release', 42),
#  ('elasticsearch', 41),
#  ('byte', 41),
#  ('shared-libraries', 41),
#  ('globalization', 41),
#  ('duplicates', 41),
#  ('binary-tree', 41),
#  ('upgrade', 41),
#  ('camera', 41),
#  ('swt', 41),
#  ('gzip', 41),
#  ('blob', 41),
#  ('nhibernate-mapping', 41),
#  ('primary-key', 41),
#  ('flex3', 41),
#  ('sybase', 41),
#  ('arm', 41),
#  ('soa', 41),
#  ('mootools', 41),
#  ('projects-and-solutions', 41),
#  ('elisp', 41),
#  ('wxwidgets', 41),
#  ('complexity-theory', 40),
#  ('visualization', 40),
#  ('rotation', 40),
#  ('request', 40),
#  ('authorization', 40),
#  ('flask', 40),
#  ('phpunit', 40),
#  ('overloading', 40),
#  ('couchdb', 40),
#  ('uiwebview', 40),
#  ('whitespace', 40),
#  ('c#-2.0', 40),
#  ('size', 40),
#  ('flexbuilder', 40),
#  ('datepicker', 40),
#  ('logic', 40),
#  ('xquery', 40),
#  ('static-analysis', 40),
#  ('language-design', 40),
#  ('rhino-mocks', 40),
#  ('diagram', 40),
#  ('embed', 39),
#  ('beautifulsoup', 39),
#  ('cmake', 39),
#  ('profiler', 39),
#  ('locale', 39),
#  ('repeater', 39),
#  ('cluster-computing', 39),
#  ('location', 39),
#  ('g++', 39),
#  ('click', 39),
#  ('character', 39),
#  ('pdf-generation', 39),
#  ('uinavigationcontroller', 39),
#  ('communication', 39),
#  ('cocos2d-iphone', 39),
#  ('try-catch', 39),
#  ('cpu', 39),
#  ('visual-c++-6', 39),
#  ('rake', 38),
#  ('pygame', 38),
#  ('bluetooth', 38),
#  ('heap-memory', 38),
#  ('task', 38),
#  ('tinymce', 38),
#  ('benchmarking', 38),
#  ('imagemagick', 38),
#  ('progress-bar', 38),
#  ('wss', 38),
#  ('base64', 38),
#  ('alignment', 38),
#  ('translation', 38),
#  ('contextmenu', 38),
#  ('youtube', 38),
#  ('ibm-midrange', 38),
#  ('posix', 38),
#  ('xml-rpc', 38),
#  ('user-input', 38),
#  ('sass', 37),
#  ('wysiwyg', 37),
#  ('load', 37),
#  ('ionic-framework', 37),
#  ('excel-2007', 37),
#  ('selenium-webdriver', 37),
#  ('trace', 37),
#  ('mime', 37),
#  ('nullpointerexception', 37),
#  ('ironpython', 37),
#  ('protocols', 37),
#  ('command-line-interface', 37),
#  ('abstract-class', 37),
#  ('deadlock', 37),
#  ('activemq', 37),
#  ('pivot', 37),
#  ('ocaml', 37),
#  ('hql', 37),
#  ('greasemonkey', 37),
#  ('xamarin', 37),
#  ('scheduled-tasks', 37),
#  ('jenkins', 37),
#  ('symbian', 37),
#  ('decimal', 37),
#  ('database-connection', 37),
#  ('uri', 37),
#  ('awt', 37),
#  ('lamp', 37),
#  ('x11', 37),
#  ('weblogic', 37),
#  ('com-interop', 37),
#  ('qa', 37),
#  ('teamcity', 37),
#  ('single-sign-on', 37),
#  ('subdomain', 37),
#  ('app-config', 37),
#  ('google-sheets', 36),
#  ('sql-order-by', 36),
#  ('radio-button', 36),
#  ('delphi-7', 36),
#  ('direct3d', 36),
#  ('buffer', 36),
#  ('jtable', 36),
#  ('jpeg', 36),
#  ('firebase-realtime-database', 36),
#  ('meteor', 36),
#  ('android-emulator', 36),
#  ('markdown', 36),
#  ('google-cloud-datastore', 36),
#  ('webdav', 36),
#  ('maps', 36),
#  ('pthreads', 36),
#  ('pygtk', 36),
#  ('sql-server-express', 36),
#  ('subsonic', 36),
#  ('multicore', 36),
#  ('packages', 36),
#  ('linq-to-objects', 36),
#  ('reverse-engineering', 36),
#  ('puzzle', 36),
#  ...]

# %%
idx, values = zip(*freq_list)
frequencies = pd.Series(values, idx)
frequencies.describe()
# Out:
# count    16255.000000
# mean        17.786835
# std        175.048205
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      11112.000000
# dtype: float64

# %%
top = frequencies.head(200)
top.plot(kind='bar', figsize=(20, 10))
plt.show()
top.describe()
# Out:
# count      200.00000
# mean       819.00000
# std       1348.47927
# min        206.00000
# 25%        271.75000
# 50%        367.00000
# 75%        695.50000
# max      11112.00000
# dtype: float64

# %%
top = frequencies.head(50)
top.plot(kind='bar', figsize=(20, 10))
plt.ylabel('Nombre d\'occurences')
plt.show()
top.describe()
# Out:
# count       50.000000
# mean      2226.160000
# std       2154.634969
# min        697.000000
# 25%        880.000000
# 50%       1343.500000
# 75%       2504.250000
# max      11112.000000
# dtype: float64

# %% [markdown]
# ## Filtre des tags les moins fréquents

# %%
keeped_tags = frequencies[:50]
tags = dataset['Tags'].apply(lambda x: [tag for tag in x if tag in keeped_tags])
tags = tags[tags.str.len() != 0]
tags
# Out:
# 0                        [iphone]
# 2                  [c#, winforms]
# 4                     [ruby, xml]
# 5                           [php]
# 7           [python, sql, django]
#                    ...
# 99706                       [c++]
# 99707                      [java]
# 99708    [c#, visual-studio-2008]
# 99709                    [iphone]
# 99710                 [algorithm]
# Name: Tags, Length: 75689, dtype: object

# %%
dataset = dataset.loc[tags.index]
dataset['Tags'] = tags

# %%
dataset['Tags'].apply(lambda x: len(x)).describe()
# Out:
# count    75689.000000
# mean         1.470597
# std          0.674153
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: Tags, dtype: float64

# %% [markdown]
# # Tokenization

# %%
from langdetect import detect
lang = dataset['Body'].apply(detect)
lang
# Out:
# 0        en
# 2        en
# 4        en
# 5        en
# 7        en
#          ..
# 99706    en
# 99707    en
# 99708    en
# 99709    en
# 99710    en
# Name: Body, Length: 75689, dtype: object

# %%
dataset.drop(lang[lang != 'en'].index, inplace=True)

# %%
html_tags_re = re.compile("<.+?>|\\n|\\|\\t/g")
posts = dataset['Body'].str.replace(html_tags_re, '')

# %% [markdown]
# ### Intermediate export

# %%
# %store dataset
# Out:
# Stored 'dataset' (DataFrame)

# %%
tokenizer = nltk.RegexpTokenizer(r'[a-zA-Z]+')
tokens = posts.str.lower().map(tokenizer.tokenize)
tokens
# Out:
# 0        [i, have, a, uiimageview, that, i, have, alrea...
# 2        [the, requirements, i, m, up, againstabout, pe...
# 4        [i, am, using, the, xml, simple, gem, inside, ...
# 5        [i, m, trying, to, get, a, php, array, that, i...
# 7        [i, have, done, some, google, searching, and, ...
#                                ...
# 99706    [so, i, m, trying, to, get, rid, of, my, std, ...
# 99707    [is, it, possible, to, have, a, singleton, in,...
# 99708    [i, was, wondering, if, there, is, some, optio...
# 99709    [i, have, found, the, getting, started, docume...
# 99710    [i, have, a, d, area, with, dots, distributed,...
# Name: Body, Length: 75481, dtype: object

# %% [markdown]
# ## Nombre de mots par post

# %%
posts_size = tokens.map(len)
posts_size.plot.hist(bins=np.arange(0, 200, 20))
plt.xlabel('Nombre de mots par post')
plt.axvline(x=posts_size.quantile(), color='red', linestyle='--')
plt.show()
posts_size.describe()
# Out:
# count    75481.000000
# mean       136.967038
# std        147.881282
# min          2.000000
# 25%         58.000000
# 50%         99.000000
# 75%        167.000000
# max       4061.000000
# Name: Body, dtype: float64

# %% [markdown]
# ## Nombre de mots uniques par post

# %%
posts_unique_size = tokens.map(lambda x: len(np.unique(x)))
posts_unique_size.plot.hist(bins=np.arange(0,200,20))
plt.xlabel('Nombre de mots uniques par post')
plt.axvline(x=posts_unique_size.quantile(), color='red', linestyle='--')
plt.show()
posts_unique_size.describe()
# Out:
# count    75481.000000
# mean        72.696612
# std         44.946087
# min          2.000000
# 25%         42.000000
# 50%         63.000000
# 75%         93.000000
# max        566.000000
# Name: Body, dtype: float64

# %%
plt.hist([posts_size, posts_unique_size], bins=np.arange(0,200,20), histtype='step')
plt.ylabel('Frequence')
plt.xlabel('Nombre de mots par post')

# Draw 50% quantile
cmap = plt.get_cmap("tab10")
plt.axvline(x=posts_size.quantile(), color=cmap(0), linestyle='--')
plt.axvline(x=posts_unique_size.quantile(), color=cmap(1), linestyle='--')

plt.legend(['Mots uniques/post', 'Mots/post'])
plt.show()

# %% [markdown]
# # Recherche des mots les plus courants

# %%
vocabulary = tokens.to_frame().apply(lambda x : pd.Series([x['Body'], nltk.FreqDist(x['Body'])], index=['tokens', 'frequency']), axis=1, result_type='expand')
vocabulary
# Out:
#                                                   tokens  \
# 0      [i, have, a, uiimageview, that, i, have, alrea...
# 2      [the, requirements, i, m, up, againstabout, pe...
# 4      [i, am, using, the, xml, simple, gem, inside, ...
# 5      [i, m, trying, to, get, a, php, array, that, i...
# 7      [i, have, done, some, google, searching, and, ...
# ...                                                  ...
# 99706  [so, i, m, trying, to, get, rid, of, my, std, ...
# 99707  [is, it, possible, to, have, a, singleton, in,...
# 99708  [i, was, wondering, if, there, is, some, optio...
# 99709  [i, have, found, the, getting, started, docume...
# 99710  [i, have, a, d, area, with, dots, distributed,...
#
#                                                frequency
# 0      {'i': 6, 'have': 2, 'a': 3, 'uiimageview': 4, ...
# 2      {'the': 16, 'requirements': 1, 'i': 3, 'm': 1,...
# 4      {'i': 1, 'am': 1, 'using': 1, 'the': 5, 'xml':...
# 5      {'i': 3, 'm': 1, 'trying': 1, 'to': 3, 'get': ...
# 7      {'i': 4, 'have': 2, 'done': 1, 'some': 2, 'goo...
# ...                                                  ...
# 99706  {'so': 2, 'i': 7, 'm': 3, 'trying': 2, 'to': 1...
# 99707  {'is': 1, 'it': 1, 'possible': 1, 'to': 1, 'ha...
# 99708  {'i': 2, 'was': 1, 'wondering': 1, 'if': 1, 't...
# 99709  {'i': 4, 'have': 1, 'found': 1, 'the': 3, 'get...
# 99710  {'i': 2, 'have': 1, 'a': 2, 'd': 1, 'area': 2,...
#
# [75481 rows x 2 columns]

# %%
dfs = [pd.DataFrame.from_dict(value, orient='index') for value in vocabulary['frequency'].values]
dfs
# Out:
# [              0
#  i             6
#  have          2
#  a             3
#  uiimageview   4
#  that          3
#  already       1
#  set           3
#  an            1
#  image        11
#  to            3
#  this          1
#  works         1
#  fine          1
#  but           2
#  later         1
#  want          1
#  change        1
#  so            1
#  new           1
#  for           1
#  the           4
#  property      1
#  when          1
#  view          1
#  app           1
#  is            1
#  as            1
#  second        1
#  over          1
#  first         1
#  cell          1
#  viewwithtag   1
#  uiimage       1
#  imagenamed    1
#  history       1
#  row           1
#  png           1
#  how           1
#  can           1
#  replace       1
#  current       1
#  in            1
#  my            1
#  rather        1
#  than          1
#  seeming       1
#  add           1
#  another       1,
#                 0
#  the           16
#  requirements   1
#  i              3
#  m              1
#  up             3
#  ...           ..
#  after          1
#  event          1
#  has            1
#  been           1
#  cancelled      1
#
#  [106 rows x 1 columns],
#              0
#  i           1
#  am          1
#  using       1
#  the         5
#  xml         3
#  simple      2
#  gem         1
#  inside      1
#  a           3
#  rake        1
#  task        1
#  to          3
#  parse       1
#  contents    1
#  of          1
#  db          1
#  dump        1
#  problem     1
#  is          2
#  that        2
#  database    1
#  file        1
#  contains    1
#  characters  1
#  like        1
#  those       1
#  in          1
#  title       1
#  causes      1
#  crash       1
#  there       1
#  work        1
#  around      1
#  this        1,
#            0
#  i         3
#  m         1
#  trying    1
#  to        3
#  get       2
#  a         4
#  php       1
#  array     1
#  that      1
#  includes  1
#  simple    2
#  nested    1
#  list      1
#  of        1
#  primary   1
#  links     1
#  and       1
#  their     1
#  sub       1
#  menu      1
#  items     1
#  this      1
#  seems     1
#  like      1
#  task      1
#  but       1
#  can       1
#  t         1
#  seem      1
#  straight  1
#  answer    1
#  on        1
#  how       1
#  exactly   2
#  do        1
#  it        2
#  from      1
#  there     1
#  would     1
#  theme     1
#  as        1
#  needed    1
#  thanks    1,
#               0
#  i            4
#  have         2
#  done         1
#  some         2
#  google       1
#  ...         ..
#  name         1
#  definedi     1
#  think        1
#  recognizing  1
#  quot         2
#
#  [84 rows x 1 columns],
#              0
#  how         1
#  to          4
#  modify      1
#  the         6
#  system      1
#  ...        ..
#  includedir  2
#  d           2
#  conf        1
#  mysqld      1
#  logging     1
#
#  [101 rows x 1 columns],
#               0
#  this         2
#  is           2
#  a            1
#  full         1
#  screen       1
#  view         1
#  of           1
#  the          1
#  amazon       1
#  websitethis  1
#  responsive   1
#  viewi        1
#  want         1
#  to           1
#  do           2
#  like         1
#  how          1
#  can          1
#  i            1
#  that         1
#  using        1
#  css          1,
#            0
#  good      1
#  day       1
#  i         7
#  have      1
#  a         1
#  ...      ..
#  mistaken  1
#  did       1
#  cause     1
#  issue     1
#  lib       1
#
#  [78 rows x 1 columns],
#                0
#  i             4
#  am            1
#  having        1
#  trouble       1
#  implementing  1
#  ...          ..
#  resultmodel   1
#  frombody      1
#  userid        1
#  do            1
#  something     1
#
#  [135 rows x 1 columns],
#             0
#  i          3
#  m          2
#  using      2
#  firebase   1
#  remote     1
#  config     2
#  and        3
#  with       2
#  my         1
#  current    1
#  setup      1
#  the        3
#  only       2
#  way        1
#  to         4
#  make       1
#  released   2
#  user       1
#  correct    1
#  version    4
#  is         2
#  by         1
#  regex      3
#  looking    1
#  for        2
#  a          4
#  that       1
#  match      6
#  any        2
#  later      2
#  than       2
#  b          3
#  cso        1
#  if         1
#  new        1
#  x          3
#  y          3
#  z          2
#  then       1
#  following  1
#  must       1
#  be         1
#  true       1
#  it         2
#  gt         3
#  or         3
#  c          1
#  real       1
#  number     1
#  example    1
#  equal      1
#  don        1
#  t          2
#  have       1
#  tried      1
#  this       1
#  but        1
#  doesn      1,
#              0
#  i           3
#  ve          1
#  developed   1
#  a           1
#  nodejs      1
#  app         1
#  and         2
#  made        1
#  exe         4
#  out         2
#  of          3
#  it          1
#  using       2
#  npm         1
#  library     1
#  called      1
#  quot        8
#  pkg         1
#  now         1
#  while       1
#  command     2
#  prompt      2
#  if          1
#  run         1
#  that        1
#  script      3
#  open        1
#  in          1
#  the         1
#  location    1
#  type        1
#  hit         1
#  enter       1
#  button      1
#  then        1
#  m           1
#  getting     1
#  javascript  1
#  heap        1
#  memory      1
#  error       1
#  how         1
#  to          1
#  resolve     1
#  itt         1,
#              0
#  i           7
#  am          2
#  new         1
#  to          7
#  javascript  2
#  ...        ..
#  was         1
#  thanks      2
#  your        1
#  responses   1
#  swati       1
#
#  [92 rows x 1 columns],
#               0
#  our          6
#  java         1
#  server       7
#  application  1
#  logs         2
#  ...         ..
#  udfs         1
#  such         1
#  way          1
#  thanks       1
#  eric         1
#
#  [196 rows x 1 columns],
#            0
#  how       1
#  to        1
#  do        1
#  a         1
#  zoom      1
#  in        1
#  out       1
#  with      1
#  wxpython  1
#  what      1
#  are       1
#  the       1
#  very      1
#  basics    1
#  for       1
#  this      2
#  purpose   1
#  i         1
#  googled   1
#  but       1
#  could     1
#  not       1
#  find      1
#  much      1
#  thanks    1,
#           0
#  we       3
#  want     2
#  to       9
#  test     3
#  a        8
#  ...     ..
#  if       1
#  another  1
#  solve    1
#  problem  1
#  thanks   1
#
#  [94 rows x 1 columns],
#           0
#  this     1
#  is       4
#  really   1
#  strange  1
#  i        5
#  ...     ..
#  number   1
#  as       1
#  well     1
#  no       1
#  avail    1
#
#  [158 rows x 1 columns],
#               0
#  is           1
#  there        2
#  a            1
#  prescribed   1
#  way          1
#  to           2
#  clean        1
#  up           1
#  ruby         2
#  gems         2
#  which        1
#  have         2
#  native       1
#  extensions   1
#  that         1
#  failed       1
#  build        1
#  are          1
#  directories  1
#  files        1
#  left         1
#  in           1
#  the          1
#  directory    1
#  however      1
#  gem          1
#  list         2
#  local        1
#  does         1
#  not          1
#  them         1
#  as           1
#  being        1
#  installed    1
#  e            1
#  g            1
#  sqlite       1
#  linecache    1
#  mongo        1,
#             0
#  we         1
#  have       4
#  a          5
#  public    10
#  calendar   9
#  ...       ..
#  appoint    3
#  subject    2
#  br         3
#  date       1
#  start      1
#
#  [225 rows x 1 columns],
#                0
#  let           1
#  s             1
#  say           1
#  i             3
#  have          1
#  this         13
#  jquery        1
#  extension     1
#  method        1
#  fn            3
#  foobar        3
#  function      4
#  var           7
#  clone         9
#  parent        3
#  after         1
#  ve            1
#  gotten        1
#  how           1
#  can           1
#  find          2
#  the           2
#  cloned        1
#  child         1
#  element       1
#  that          1
#  is            1
#  same          1
#  as            1
#  will          1
#  work          1
#  cloneofthis   3
#  or            1
#  self          2
#  children      1
#  each          1
#  if            1,
#                        0
#  public                6
#  class                 2
#  richtextboxextended  13
#  richtextbox           1
#  static                3
#  ...                  ..
#  dev                   1
#  line                  1
#  ctor                  1
#  viewmodel             1
#  now                   1
#
#  [190 rows x 1 columns],
#            0
#  i         9
#  want      3
#  to        3
#  select    2
#  the      18
#  ...      ..
#  anyone    1
#  an        1
#  idea      1
#  can       1
#  version   1
#
#  [115 rows x 1 columns],
#            0
#  for       1
#  i         7
#  to        3
#  n         4
#  do        2
#  j         4
#  while     2
#  lt        1
#  m         1
#  really    1
#  confused  1
#  when      1
#  it        3
#  comes     1
#  big       1
#  o         2
#  notation  1
#  so        1
#  d         1
#  like      1
#  know      3
#  if        1
#  s         2
#  log       2
#  that      1
#  my        1
#  gut       1
#  but       2
#  can       1
#  t         2
#  prove     1
#  the       2
#  loop      1
#  is        1
#  probably  1
#  faster    1
#  than      1
#  don       1
#  by        1
#  how       1
#  much      1
#  edit      1
#  caret     1
#  denotes   1
#  exponent  1,
#           0
#  so       2
#  in       7
#  my       2
#  php      2
#  code     1
#  ...     ..
#  savings  1
#  no       1
#  clue     1
#  please   1
#  help     1
#
#  [85 rows x 1 columns],
#             0
#  i          6
#  have       2
#  made       1
#  the        5
#  following  1
#  ...       ..
#  hello      1
#  print      7
#  press      1
#  or         1
#  space      1
#
#  [120 rows x 1 columns],
#            0
#  so        1
#  i        13
#  changed   1
#  path      2
#  to        4
#  ...      ..
#  or        1
#  be        1
#  an        1
#  easy      1
#  fix       1
#
#  [99 rows x 1 columns],
#            0
#  i        10
#  have      5
#  found     1
#  several   1
#  topics    1
#  ...      ..
#  don       1
#  t         1
#  like      1
#  give      1
#  up        1
#
#  [153 rows x 1 columns],
#           0
#  i       12
#  ve       1
#  been     1
#  trying   1
#  to       6
#  ...     ..
#  when     1
#  life     1
#  little   1
#  less     1
#  hectic   1
#
#  [148 rows x 1 columns],
#             0
#  i         12
#  need       3
#  to        14
#  make       2
#  multiple   4
#  ...       ..
#  has        1
#  finished   2
#  tell       1
#  etc        1
#  thoughts   1
#
#  [139 rows x 1 columns],
#              0
#  okay        2
#  i          11
#  m           1
#  building    1
#  a           4
#  ...        ..
#  did         1
#  something   1
#  findby      1
#  getparam    1
#  setactive   1
#
#  [271 rows x 1 columns],
#           0
#  i        5
#  tried    1
#  to       1
#  create   1
#  a        2
#  ...     ..
#  can      1
#  someone  1
#  help     1
#  me       1
#  issue    1
#
#  [64 rows x 1 columns],
#                    0
#  i                 4
#  am                1
#  using             3
#  constraintlayout  6
#  and               1
#  ...              ..
#  toleftof          1
#  constraintright   1
#  torightof         1
#  margintop         1
#  ffffff            1
#
#  [97 rows x 1 columns],
#           0
#  i        3
#  was      1
#  having   1
#  some     1
#  problem  1
#  ...     ..
#  way      1
#  based    1
#  on       1
#  of       1
#  thanks   1
#
#  [93 rows x 1 columns],
#             0
#  i          2
#  ve         1
#  read       1
#  so         2
#  many       1
#  other      1
#  answers    1
#  to         3
#  such       1
#  questions  1
#  but        1
#  they       1
#  don        2
#  t          2
#  work       1
#  please     1
#  mark       1
#  it         1
#  duplicate  1
#  m          1
#  a          1
#  python     2
#  self       7
#  learner    1
#  running    1
#  on         2
#  windows    1
#  in         1
#  this       2
#  is         2
#  the        3
#  code       2
#  btncalc    3
#  button     1
#  text       1
#  calculate  4
#  command    1
#  bd         1
#  grid       1
#  row        1
#  column     1
#  bind       1
#  lt         1
#  return     1
#  gt         1
#  link       1
#  whole      1
#  school     1
#  grades     1,
#              0
#  i           5
#  am          1
#  trying      2
#  to          5
#  print       4
#  ...        ..
#  background  1
#  color       1
#  c           3
#  jsfiddle    1
#  here        1
#
#  [71 rows x 1 columns],
#                       0
#  i                    4
#  am                   1
#  creating             1
#  an                   2
#  app                  2
#  ...                 ..
#  contacttestbitmask   1
#  isaffectedbygravity  1
#  falsescene           1
#  rootnode             1
#  addchildnode         1
#
#  [79 rows x 1 columns],
#           0
#  i        3
#  want     2
#  to       3
#  assign   1
#  props    4
#  ...     ..
#  work     1
#  advance  1
#  thanks   1
#  for      1
#  help     1
#
#  [98 rows x 1 columns],
#              0
#  android     2
#  guidelines  1
#  are         1
#  now         1
#  to          4
#  ...        ..
#  setting     1
#  true        1
#  execute     1
#  every       1
#  time        1
#
#  [82 rows x 1 columns],
#               0
#  i            5
#  have         1
#  a            2
#  submit       3
#  button       4
#  that         2
#  runs         1
#  script       3
#  when         1
#  clicking     2
#  on           4
#  it           2
#  lt           3
#  input        1
#  type         1
#  value        1
#  download     1
#  files        2
#  class        2
#  btn          3
#  success      1
#  col          1
#  md           1
#  id           1
#  load         1
#  data         1
#  loading      3
#  text         1
#  fa           3
#  circle       1
#  o            1
#  notch        1
#  spin         1
#  gt           3
#  downloading  1
#  click        1
#  function     2
#  var          1
#  this         4
#  settimeout   1
#  reset        1
#  the          4
#  running      2
#  time         3
#  is           1
#  not          1
#  constant     1
#  varies       1
#  from         1
#  to           2
#  want         1
#  start        1
#  and          1
#  end          1
#  after        1
#  finishes     1
#  how          1
#  can          1
#  do           1,
#            0
#  i        13
#  am        1
#  trying    1
#  to        7
#  present   1
#  ...      ..
#  style     4
#  width     4
#  height    4
#  thanks    1
#  advice    1
#
#  [243 rows x 1 columns],
#           0
#  i       14
#  have     3
#  a        6
#  sql      1
#  server   1
#  ...     ..
#  out      1
#  what     1
#  should   1
#  doing    1
#  thanks   1
#
#  [98 rows x 1 columns],
#              0
#  i           3
#  don         1
#  t           1
#  know        1
#  why         2
#  m           1
#  seeing      1
#  the         2
#  below       1
#  const       2
#  sidelength  3
#  multiarray  7
#  new         2
#  array       3
#  fill        1
#  console     3
#  log         2
#  var         1
#  counter     2
#  output      2
#  would       1
#  have        1
#  expected    1
#  second      1
#  line        1
#  of          1
#  to          2
#  be          1
#  is          1
#  that        1
#  being       1
#  added       1
#  every       1
#  s           1
#  index       1
#  element     1,
#               0
#  i            2
#  have         1
#  an           1
#  angular      1
#  application  1
#  and          1
#  am           1
#  loading      1
#  some         1
#  videos       1
#  with         1
#  html         1
#  video        2
#  tags         1
#  need         1
#  for          1
#  only         1
#  one          1
#  to           1
#  play         1
#  at           1
#  a            1
#  time         1,
#               0
#  i            9
#  have         1
#  csv          6
#  file         4
#  that         2
#  am           3
#  performing   1
#  so           1
#  function     1
#  for          2
#  each         2
#  row          5
#  in           1
#  the          6
#  np           2
#  genfromtxt   1
#  nsndatabase  1
#  dtype        1
#  str          1
#  delimiter    1
#  skip         1
#  header       1
#  once         1
#  done         2
#  using        1
#  want         1
#  to           1
#  delete       3
#  from         2
#  tried        2
#  this         2
#  nsn          2
#  is           1
#  what         1
#  named        1
#  above        1
#  code         1
#  does         1
#  not          1
#  work         1
#  without      1
#  asterics     1
#  but          1
#  yielded      1
#  error        1
#  invalid      1
#  literal      1
#  int          1
#  with         2
#  base         1
#  how          1
#  can          1
#  after        1
#  it           1,
#                            0
#  i                         2
#  m                         1
#  crazy                     1
#  about                     1
#  this                      1
#  parsing                   1
#  code                      1
#  as                        1
#  below                     1
#  try                       1
#  string                    1
#  if                        3
#  modified                  3
#  since                     3
#  sat                       2
#  sep                       2
#  cst                       2
#  datetimeformatter         4
#  datetimeformat            1
#  forpattern                1
#  eee                       1
#  mmm                       1
#  dd                        1
#  hh                        1
#  mm                        1
#  ss                        1
#  zzz                       1
#  yyyy                      1
#  datetime                  2
#  dt                        1
#  parse                     1
#  catch                     2
#  exception                 1
#  e                         2
#  todo                      1
#  auto                      1
#  generated                 1
#  block                     1
#  printstacktrace           1
#  the                       1
#  error                     1
#  message                   1
#  is                        1
#  java                      1
#  lang                      1
#  illegalargumentexception  1
#  invalid                   1
#  format                    1
#  tried                     1
#  withlocale                1
#  locale                    1
#  us                        1
#  it                        2
#  didn                      1
#  t                         1
#  work                      1
#  how                       1
#  to                        1
#  fix                       1,
#                        0
#  hello                 1
#  i                     2
#  have                  1
#  getsharedpreferences  3
#  cannot                1
#  ...                  ..
#  urls                  3
#  gettext               2
#  tostring              2
#  putextra              1
#  startactivity         1
#
#  [62 rows x 1 columns],
#               0
#  i            1
#  use          1
#  the          7
#  woocommerce  5
#  product      3
#  ...         ..
#  isset        2
#  array        2
#  reviews      2
#  true         2
#  endif        3
#
#  [92 rows x 1 columns],
#               0
#  i            1
#  have         1
#  an           1
#  application  4
#  hosted       1
#  ...         ..
#  does         1
#  anyone       1
#  know         1
#  why          1
#  thanks       1
#
#  [200 rows x 1 columns],
#             0
#  maybe      1
#  it         4
#  is         3
#  because    1
#  i          6
#  ...       ..
#  hope       1
#  question   1
#  makes      1
#  sense      1
#  community  1
#
#  [66 rows x 1 columns],
#                       0
#  i                    8
#  m                    2
#  trying               1
#  to                   3
#  pass                 2
#  ...                 ..
#  price                1
#  formattedtotalprice  1
#  billinginfo          1
#  status               1
#  default              1
#
#  [171 rows x 1 columns],
#               0
#  i            8
#  ve           2
#  been         1
#  trying       1
#  to           3
#  ...         ..
#  any          1
#  help         1
#  would        1
#  greatly      1
#  appreciated  1
#
#  [79 rows x 1 columns],
#             0
#  i          6
#  developed  1
#  a          3
#  new        1
#  version    1
#  ...       ..
#  console    1
#  refuses    1
#  apkthank   1
#  you        1
#  max        1
#
#  [72 rows x 1 columns],
#              0
#  borrowing   1
#  from        4
#  the        17
#  get         2
#  method      5
#  ...        ..
#  best        1
#  yet         1
#  see         1
#  reached     1
#  stop        1
#
#  [183 rows x 1 columns],
#         0
#  i      5
#  work   1
#  on     1
#  a     11
#  new    1
#  ...   ..
#  do     1
#  you    1
#  any    1
#  idea   1
#  this   1
#
#  [119 rows x 1 columns],
#               0
#  i            4
#  am           1
#  clicking     1
#  an           1
#  link         1
#  with         2
#  selenium     1
#  and          2
#  it           1
#  is           5
#  opening      1
#  a            3
#  new          1
#  browser      2
#  tab          2
#  pdf          3
#  want         2
#  to           3
#  know         1
#  if           2
#  there        1
#  way          1
#  dowload      1
#  that         2
#  don          1
#  t            1
#  care         1
#  the          2
#  open         1
#  then         1
#  downloading  1
#  started      1
#  what         1
#  download     1
#  thanks       1,
#              0
#  i           3
#  have        2
#  table       1
#  which       1
#  has         1
#  ...        ..
#  lt          1
#  in          1
#  group       1
#  by          2
#  typehaving  1
#
#  [63 rows x 1 columns],
#             0
#  i          3
#  have       1
#  a          5
#  docker     3
#  file       1
#  ...       ..
#  also       1
#  it         1
#  different  1
#  if         1
#  possible   1
#
#  [93 rows x 1 columns],
#                 0
#  since          2
#  i              7
#  installed      1
#  xcode          6
#  have           1
#  ...           ..
#  has            1
#  changed        1
#  documentation  1
#  thanks         1
#  advance        1
#
#  [106 rows x 1 columns],
#                       0
#  i                    2
#  am                   1
#  getting              1
#  the                  7
#  below                1
#  ...                 ..
#  dataaccessexception  1
#  dae                  2
#  getlocalizedmessage  1
#  complete             1
#  return               1
#
#  [89 rows x 1 columns],
#             0
#  here       1
#  is         6
#  a          8
#  snippet    1
#  of         7
#  ...       ..
#  arguments  3
#  if         1
#  values     2
#  this       2
#  case       2
#
#  [83 rows x 1 columns],
#                     0
#  currently          2
#  i                  1
#  am                 1
#  using              1
#  code               1
#  below              1
#  but                1
#  not                2
#  able               1
#  to                 1
#  add                1
#  validate           2
#  its                1
#  regularexpression  1
#  b                  2
#  d                  3
#  errormessage       1
#  please             1
#  enter              1
#  valid              1
#  mobile             1
#  no                 1,
#               0
#  so           1
#  i            3
#  am           2
#  currently    1
#  trying       1
#  ...         ..
#  help         1
#  appreciated  1
#  thanks       1
#  in           1
#  advance      1
#
#  [129 rows x 1 columns],
#            0
#  i         2
#  wanna     1
#  setting   3
#  below     2
#  single    1
#  line      1
#  format    1
#  css       2
#  code      2
#  style     3
#  in        2
#  webstorm  2
#  not       2
#  a         1
#  space     1
#  included  1
#  after     1
#  the       2
#  opening   1
#  brace     2
#  and       2
#  before    1
#  closing   1
#  h         2
#  width     2
#  px        4
#  height    2
#  but       1
#  it        1
#  does      1
#  exist     1
#  webstrom  1
#  menu      1
#  show      1
#  how       1
#  can       1
#  solving   1
#  this      1
#  problem   1,
#              0
#  i          13
#  m           4
#  currently   1
#  trying      1
#  to          2
#  ...        ..
#  up          1
#  correctly   1
#  still       1
#  get         1
#  warning     1
#
#  [121 rows x 1 columns],
#              0
#  so          1
#  i           2
#  have        1
#  this        2
#  simple      1
#  string      1
#  dgj         2
#  gjnw        2
#  gwgt        2
#  jfdhdr      2
#  report      2
#  dsdgs       2
#  ryr         2
#  y           2
#  etet        2
#  erte        2
#  neytwe      2
#  eyqw        2
#  etyer       2
#  eyey        2
#  efaewf      2
#  were        2
#  want        1
#  to          1
#  order       2
#  like        1
#  a           1
#  table       1
#  and         1
#  alignments  1
#  the         1
#  values      1
#  in          1
#  normal      1
#  for         1
#  example     1,
#               0
#  i            2
#  have         1
#  implemented  1
#  jquery       1
#  csv          7
#  library      1
#  to           2
#  parse        1
#  data         2
#  from         1
#  file         2
#  my           1
#  looks        1
#  like         1
#  this         1
#  name         5
#  description  1
#  client       9
#  address      3
#  descname     1
#  descript     2
#  desc         2
#  am           1
#  using        1
#  toobjects    1
#  var          1
#  toarrays     1
#  is           1
#  it           1
#  possible     1
#  trim         1
#  whitespace   1
#  for          1
#  headers      1,
#               0
#  i            3
#  would        1
#  like         1
#  to           3
#  add          3
#  a            2
#  custom       1
#  field        2
#  in           3
#  product      4
#  short        3
#  description  3
#  woocommerce  3
#  meta         5
#  box          5
#  this         2
#  is           3
#  already      1
#  built        1
#  but          1
#  can          1
#  t            1
#  find         1
#  way          1
#  an           1
#  extra        1
#  that         1
#  the          1
#  code         1
#  found        1
#  postexcerpt  1
#  wc           1
#  output       1
#  normal       1
#  any          1
#  help         1
#  highly       1
#  appreciated  1
#  thanks       1
#  advance      1,
#             0
#  i          2
#  m          1
#  trying     1
#  to         1
#  execute    2
#  a          1
#  remote     2
#  command    1
#  like       1
#  this       2
#  ssh        1
#  root       1
#  su         1
#  vertica    1
#  c          2
#  vsql       1
#  select     1
#  from       1
#  tablename  2
#  where      2
#  timestamp  2
#  gt         2
#  limit      1
#  it         2
#  gives      1
#  me         1
#  an         1
#  error      3
#  syntax     1
#  at         2
#  or         1
#  near       1
#  character  1
#  line       1
#  rom        1
#  l          1
#  although   1
#  when       1
#  query      1
#  directly   1
#  in         1
#  the        1
#  machine    1
#  works      1
#  just       1
#  fine       1
#  can        1
#  someone    1
#  provide    1
#  any        1
#  clues      1
#  here       1
#  please     1,
#               0
#  i            2
#  have         1
#  an           1
#  xml          8
#  that         2
#  ...         ..
#  value        4
#  body         4
#  amp         30
#  xmlversion   1
#  quot         4
#
#  [69 rows x 1 columns],
#               0
#  scope        2
#  showdetails  1
#  function     1
#  dashboard    3
#  item         3
#  ...         ..
#  tldr         1
#  want         1
#  while        1
#  passing      1
#  parameters   1
#
#  [90 rows x 1 columns],
#                 0
#  i              4
#  am             1
#  trying         1
#  to             1
#  create         2
#  a              1
#  notification   1
#  container      1
#  with           2
#  css            1
#  that           1
#  is             1
#  the            7
#  same           2
#  size           1
#  as             1
#  notifications  3
#  on             3
#  ios            1
#  my             1
#  iphone         1
#  s              1
#  have           1
#  created        1
#  screen         1
#  grabs          1
#  of             2
#  portrait       2
#  and            3
#  landscape      2
#  when           2
#  view           1
#  images         1
#  sizes          1
#  in             3
#  pixels         1
#  are            2
#  x              2
#  respectively   1
#  height         1
#  px             3
#  they           1
#  displayed      1
#  device         1
#  differently    1
#  https          1
#  www            1
#  dropbox        1
#  com            1
#  sh             1
#  bmkv           1
#  gua            1
#  r              1
#  zly            1
#  aac            1
#  xpziurwzfwcb   1
#  pfzdk          1
#  da             1
#  dl             1,
#          0
#  i       4
#  tried   1
#  to      2
#  reload  1
#  a       1
#  ...    ..
#  of      1
#  how     1
#  can     1
#  fix     1
#  it      1
#
#  [95 rows x 1 columns],
#             0
#  i          3
#  want       1
#  to         5
#  rotate     2
#  an         1
#  ...       ..
#  sampler    1
#  color      2
#  x          1
#  y          1
#  fragcolor  1
#
#  [153 rows x 1 columns],
#             0
#  lt         6
#  li         2
#  gt         6
#  strong     2
#  company    6
#  ...       ..
#  https      1
#  idn        1
#  bizdirlib  1
#  com        1
#  node       1
#
#  [101 rows x 1 columns],
#             0
#  recently   1
#  i          6
#  decide     1
#  to         4
#  make       2
#  a          2
#  framework  7
#  for        1
#  login      1
#  module     1
#  add        1
#  the        8
#  image      2
#  resources  1
#  but        2
#  could      1
#  not        2
#  get        2
#  it         3
#  by         2
#  code       1
#  change     1
#  build      1
#  setting    1
#  mach       1
#  o          1
#  type       1
#  static     2
#  library    2
#  into       1
#  dynamic    5
#  can        3
#  is         3
#  easier     1
#  moudle     1
#  with       2
#  than       1
#  google     1
#  and        1
#  find       1
#  made       1
#  developer  1
#  different  1
#  apple      1
#  s          1
#  app        1
#  contain    1
#  custom     1
#  upload     1
#  appstore   1
#  true       1
#  who        1
#  answer     1
#  my         1
#  question   1
#  thank      1
#  you        1
#  so         1
#  much       1,
#                 0
#  i              2
#  am             1
#  trying         1
#  to             2
#  implement      1
#  py             2
#  abac           3
#  for            2
#  even           2
#  if             2
#  correct        1
#  policies       1
#  are            1
#  getting        1
#  retrieved      1
#  from           1
#  the            3
#  storage        1
#  while          1
#  policy         1
#  evaluation     1
#  part           1
#  is             3
#  always         2
#  giving         2
#  quot           2
#  deny           2
#  case           1
#  tried          2
#  check          1
#  issue          1
#  and            2
#  found          1
#  that           1
#  matching       1
#  rules          1
#  also           1
#  somehow        1
#  it             1
#  none           1
#  return         1
#  there          1
#  no             1
#  resources      1
#  or             1
#  documentation  2
#  available      1
#  other          1
#  than           1
#  official       1
#  anybody        1
#  please         1
#  provide        1
#  some           1
#  lead           1
#  thanks         1
#  in             1
#  advance        1,
#               0
#  is           1
#  there        2
#  any          2
#  way          2
#  producer     3
#  ...         ..
#  go           1
#  p            2
#  and          1
#  within       1
#  meetuptopic  1
#
#  [86 rows x 1 columns],
#            0
#  i         8
#  am        4
#  new       1
#  to        5
#  this      2
#  ...      ..
#  the       1
#  client    1
#  bring     1
#  own       1
#  approach  1
#
#  [66 rows x 1 columns],
#                    0
#  i                 4
#  m                 2
#  using             2
#  httpclient       15
#  net              41
#  ...              ..
#  locations         2
#  list              2
#  log               2
#  importdata        1
#  innerexceptions   1
#
#  [243 rows x 1 columns],
#          0
#  i       4
#  am      1
#  trying  1
#  to      4
#  let     1
#  ...    ..
#  there   1
#  issue   1
#  with    1
#  how     1
#  wrote   1
#
#  [100 rows x 1 columns],
#               0
#  i            5
#  want         3
#  to           5
#  extract      2
#  the          6
#  ...         ..
#  weightnodea  1
#  nodeb        3
#  nodea        3
#  nodec        1
#  noded        2
#
#  [69 rows x 1 columns],
#           0
#  i       18
#  am       1
#  trying   1
#  to       4
#  write    1
#  ...     ..
#  tricks   1
#  code     1
#  or       1
#  major    1
#  flaws    1
#
#  [95 rows x 1 columns],
#            0
#  i         5
#  made      1
#  a         2
#  function  5
#  to        4
#  ...      ..
#  where     1
#  should    1
#  write     1
#  make      1
#  properly  1
#
#  [66 rows x 1 columns],
#             0
#  i          4
#  have       3
#  a          7
#  xls        1
#  with       1
#  ...       ..
#  immediate  1
#  select     1
#  from       1
#  where      1
#  end        1
#
#  [71 rows x 1 columns],
#                    0
#  i                10
#  m                 4
#  trying            1
#  to                6
#  install           2
#  ...              ..
#  anothercomputer   1
#  because           1
#  upload            1
#  usb               1
#  stick             1
#
#  [111 rows x 1 columns],
#          0
#  i       4
#  m       1
#  trying  1
#  to      1
#  get     2
#  ...    ..
#  add     1
#  it      1
#  any     1
#  ideas   1
#  please  1
#
#  [80 rows x 1 columns],
#               0
#  we           4
#  have         2
#  os           2
#  centos       1
#  php          5
#  firebird     3
#  apache       2
#  and          2
#  running      2
#  the          6
#  files        2
#  in           3
#  single       3
#  script       2
#  it           1
#  s            1
#  fine         1
#  here         1
#  now          1
#  changed      1
#  to           5
#  red          1
#  hat          1
#  try          1
#  run          1
#  are          2
#  facing       2
#  below        1
#  issue        2
#  warning      1
#  ibase        1
#  query        1
#  too          1
#  many         2
#  open         1
#  handles      1
#  databasewe   1
#  came         1
#  know         1
#  that         1
#  db           2
#  connections  3
#  set          2
#  default      1
#  one          1
#  connection   1
#  after        1
#  reaching     1
#  those        1
#  above        1
#  can          1
#  anyone       1
#  help         1
#  me           1
#  at           1,
#             0
#  i          1
#  m          1
#  trying     1
#  to         2
#  attach     1
#  ...       ..
#  info       1
#  output     1
#  start      2
#  dev        2
#  undefined  1
#
#  [79 rows x 1 columns],
#               0
#  i           12
#  have         2
#  a            2
#  city        11
#  model        1
#  ...         ..
#  are          1
#  fake         1
#  give         1
#  an           1
#  impression   1
#
#  [104 rows x 1 columns],
#           0
#  here     1
#  is       4
#  problem  1
#  i        9
#  m        1
#  ...     ..
#  take     1
#  chart    1
#  control  1
#  thanks   1
#  advance  1
#
#  [100 rows x 1 columns],
#            0
#  i         7
#  want      1
#  to        7
#  export    2
#  all       2
#  ...      ..
#  vs        1
#  boot      1
#  work      1
#  any       1
#  thoughts  1
#
#  [85 rows x 1 columns],
#                     0
#  i                  9
#  have               4
#  two                2
#  uilabels           1
#  in                 4
#  ...               ..
#  sizewithfont       3
#  font               3
#  constrainedtosize  3
#  linebreakmode      6
#  weffew             1
#
#  [109 rows x 1 columns],
#               0
#  title        1
#  pretty       1
#  much         1
#  explains     1
#  it           2
#  all          1
#  i            1
#  need         1
#  to           1
#  get          1
#  some         1
#  hardware     1
#  information  1
#  such         1
#  as           1
#  cpu          2
#  info         1
#  and          1
#  total        2
#  ram          2
#  with         1
#  vb           1
#  ideally      1
#  would        1
#  return       1
#  something    2
#  like         2
#  this         1
#  for          3
#  the          4
#  intel        1
#  core         1
#  quad         1
#  q            1
#  ghzand       1
#  simple       1
#  an           1
#  integer      1
#  amount       1
#  of           1
#  mb           1
#  computer     1
#  has          1,
#              0
#  basically   1
#  i           4
#  have        3
#  simple      2
#  form        1
#  ...        ..
#  uploads     1
#  duplicates  1
#  split       1
#  optimal     1
#  close       1
#
#  [108 rows x 1 columns],
#              0
#  i           5
#  was         1
#  wondering   1
#  if          1
#  there       1
#  is          1
#  a           3
#  way         1
#  to          4
#  protect     1
#  piece       1
#  of          1
#  html        1
#  or          2
#  text        1
#  inside      2
#  the         5
#  jquery      1
#  inline      1
#  content     1
#  editor      2
#  jwysiwyg    1
#  for         1
#  example     1
#  have        1
#  div         2
#  that        1
#  externally  1
#  insert      1
#  and         2
#  do          1
#  not         3
#  want        1
#  user        1
#  modify      1
#  it          2
#  could       1
#  capture     1
#  keypress    1
#  event       1
#  iframe      1
#  security    1
#  setting     1
#  readonly    1
#  disabled    1
#  did         1
#  work        1
#  any         1
#  ideas       1
#  thanks      1,
#           0
#  i        1
#  posted   1
#  this     2
#  on       1
#  msdn     2
#  ...     ..
#  run      1
#  prior    1
#  any      1
#  help     1
#  welcome  1
#
#  [61 rows x 1 columns],
#               0
#  i            4
#  have         1
#  a            4
#  class        4
#  shown        1
#  ...         ..
#  length       1
#  setout       1
#  printstream  2
#  true         2
#  seterr       1
#
#  [121 rows x 1 columns],
#              0
#  i           5
#  want        1
#  to          5
#  filter      1
#  out         1
#  ...        ..
#  file        1
#  say         1
#  makes       1
#  no          1
#  difference  1
#
#  [112 rows x 1 columns],
#          0
#  i       4
#  am      1
#  trying  1
#  to      2
#  call    1
#  ...    ..
#  hunch   1
#  can     1
#  anyone  1
#  help    1
#  me      1
#
#  [63 rows x 1 columns],
#               0
#  i            1
#  want         1
#  my           1
#  application  1
#  to           1
#  recognize    1
#  barcodes     1
#  taken        1
#  by           1
#  camera       1
#  is           1
#  it           1
#  possible     1
#  using        1
#  android      1
#  sdk          1
#  something    1
#  like         1
#  this         1
#  barcode      1
#  scanner      1,
#              0
#  how         2
#  come        1
#  the         7
#  first       1
#  call        1
#  ...        ..
#  following   1
#  method      1
#  type        1
#  moo         1
#  applicable  1
#
#  [67 rows x 1 columns],
#                 0
#  i              2
#  was            2
#  wondering      1
#  if             1
#  there          1
#  is             1
#  a              1
#  way            1
#  having         1
#  this           2
#  var            3
#  string         2
#  foo            4
#  bar            4
#  to             3
#  get            1
#  the            3
#  last           1
#  part           1
#  of             1
#  using          1
#  just           1
#  regex          1
#  trying         1
#  do             2
#  look           1
#  aheads         1
#  but            1
#  couldn         1
#  t              1
#  master         1
#  them           1
#  enough         1
#  updateperhaps  1
#  some           1
#  examples       1
#  will           1
#  make           1
#  question       1
#  clearer        1
#  st             3
#  match          3
#  should         3
#  be             3
#  aab            1
#  aabvar         1
#  no             1
#  found          1,
#             0
#  all        3
#  i         11
#  am         2
#  trying     1
#  to        12
#  ...       ..
#  more       1
#  code       1
#  myself     1
#  look       1
#  evidence   1
#
#  [141 rows x 1 columns],
#               0
#  this         4
#  has          1
#  been         1
#  driving      1
#  be           2
#  ...         ..
#  any          1
#  suggestions  1
#  what         1
#  possibly     1
#  do           1
#
#  [133 rows x 1 columns],
#              0
#  i           2
#  have        1
#  around      1
#  entries     1
#  in          4
#  mongodb     1
#  the         2
#  following   1
#  format      1
#  feature     3
#  category    3
#  countwhere  1
#  could       1
#  be          1
#  any         2
#  word        1
#  is          1
#  positive    1
#  or          2
#  negative    1
#  and         1
#  count       1
#  tells       1
#  how         2
#  many        1
#  times       1
#  a           2
#  occurred    1
#  document    1
#  for         1
#  that        1
#  want        1
#  to          3
#  cache       2
#  top         1
#  tuples      1
#  let         1
#  s           1
#  say         1
#  so          1
#  as          1
#  not         1
#  query       1
#  database    1
#  each        1
#  time        1
#  does        1
#  one         1
#  build       1
#  an          1
#  lru         1
#  python      1
#  are         1
#  there       1
#  known       1
#  solutions   1
#  this        1,
#           0
#  ok       1
#  guys     1
#  so       1
#  i        7
#  am       5
#  ...     ..
#  correct  1
#  onto     1
#  thanks   1
#  ahead    1
#  time     1
#
#  [216 rows x 1 columns],
#                                   0
#  how                              1
#  to                               1
#  find                             1
#  and                              1
#  replace                          1
#  every                            2
#  occurrence                       1
#  ofhttpaccesswithhttpaccessabcin  1
#  file                             1
#  of                               1
#  name                             1
#  access                           1
#  html                             1
#  in                               1
#  a                                1
#  particular                       1
#  folder                           1,
#               0
#  android     37
#  studio       1
#  this         5
#  is           6
#  what         1
#  ...         ..
#  marginend    1
#  trending     1
#  down         1
#  tvlastsale   1
#  vertical     1
#
#  [106 rows x 1 columns],
#               0
#  i            3
#  have         2
#  a            1
#  table        1
#  that         1
#  want         1
#  to           1
#  select       2
#  data         1
#  by           3
#  my           1
#  date         1
#  end          4
#  in           1
#  descending   1
#  order        2
#  and          1
#  then         1
#  reorder      1
#  key          3
#  from         1
#  payschedule  1
#  where        1
#  lt           1
#  curdate      1
#  desc         1
#  asclimit     1
#  for          1
#  example      1
#  if           1
#  current      1
#  datemy       1
#  query        1
#  should       1
#  return       1,
#                  0
#  how             1
#  to              5
#  allow           1
#  my              1
#  c               5
#  ...            ..
#  failed          1
#  retrieve        1
#  valid           1
#  authentication  1
#  user            1
#
#  [134 rows x 1 columns],
#             0
#  i          7
#  am         2
#  learning   1
#  c          1
#  by         1
#  ...       ..
#  exist      2
#  make       3
#  that       1
#  beautiful  1
#  thanks     1
#
#  [77 rows x 1 columns],
#            0
#  i         3
#  made      1
#  asp       1
#  net       1
#  web       2
#  page      3
#  with      1
#  lt        5
#  iframe    3
#  gt        5
#  body      2
#  src       1
#  http      1
#  example   1
#  com       1
#  when      2
#  inspect   1
#  that      2
#  in        3
#  chrome    1
#  recive    1
#  some      2
#  message   2
#  console   1
#  consolei  1
#  need      1
#  grab      1
#  and       1
#  find      1
#  specific  1
#  text      1
#  do        1
#  staff     1
#  my        1
#  any       1
#  solution  1
#  is        1
#  welcome   1,
#          0
#  i       5
#  m       1
#  new     3
#  at      1
#  django  1
#  ...    ..
#  if      1
#  set     1
#  save    1
#  print   1
#  you     1
#
#  [80 rows x 1 columns],
#              0
#  context     1
#  i          12
#  ve          1
#  built       1
#  a           5
#  ...        ..
#  since       1
#  variable    1
#  names       1
#  after       1
#  populated   1
#
#  [243 rows x 1 columns],
#              0
#  i           5
#  m           2
#  having      1
#  trouble     1
#  with        4
#  ...        ..
#  how         1
#  write       1
#  an          1
#  sqlalchemy  1
#  thanks      1
#
#  [86 rows x 1 columns],
#                   0
#  why              1
#  do               1
#  this             2
#  catch            2
#  sqlexception     2
#  sqle             4
#  printstacktrace  2
#  finally          1
#  cs               2
#  close            4
#  rs               2
#  instead          1
#  of               1,
#              0
#  i          11
#  have        3
#  an          2
#  out         2
#  of          3
#  ...        ..
#  or          1
#  figure      1
#  translate   1
#  core        1
#  idea        1
#
#  [150 rows x 1 columns],
#          0
#  i       6
#  m       1
#  trying  1
#  to      3
#  get     2
#  ...    ..
#  aop     1
#  how     1
#  do      1
#  you     1
#  thanks  1
#
#  [80 rows x 1 columns],
#             0
#  what       1
#  s          1
#  the        2
#  best       1
#  way        1
#  to         1
#  replace    1
#  arrow      1
#  image      1
#  in         1
#  a          2
#  dropdown   1
#  with       1
#  different  1
#  one        1,
#            0
#  i        11
#  am        3
#  writing   1
#  an        2
#  ipad      1
#  ...      ..
#  with      1
#  thanks    1
#  advance   1
#  any       1
#  help      1
#
#  [130 rows x 1 columns],
#           0
#  how      1
#  can      1
#  i        1
#  convert  1
#  list     2
#  in       2
#  string   1
#  erlang   1
#  my       1
#  view     1
#  fff      1
#  asdfff   1
#  thank    1
#  you      1,
#          0
#  i       7
#  m       2
#  trying  1
#  to      7
#  build   1
#  ...    ..
#  t       1
#  want    1
#  do      1
#  due     1
#  size    1
#
#  [68 rows x 1 columns],
#                0
#  i             5
#  m             3
#  trying        1
#  to            3
#  navigate      1
#  a             3
#  page          6
#  using         2
#  routerlink    2
#  after         1
#  getting       1
#  an            1
#  id            8
#  which         1
#  can           1
#  get           1
#  the           3
#  problem       1
#  is            2
#  link          1
#  showing       1
#  up            1
#  as            2
#  component     6
#  would         1
#  like          1
#  for           1
#  it            1
#  show          1
#  not           1
#  matrix        1
#  notation      1
#  no            1
#  in            3
#  my            2
#  app           1
#  routes        1
#  ts            1
#  routerconfig  1
#  path          1
#  mycomponent   1
#  data          1
#  item          2
#  lt            1
#  gt            1
#  latest        1
#  angular       1
#  router        1
#  rc            1
#  beta          1
#  anyone        1
#  know          1
#  what          1
#  doing         1
#  wrong         1
#  thanks        1
#  advance       1,
#               0
#  i           13
#  am           1
#  writing      1
#  a            4
#  program      4
#  ...         ..
#  exception    1
#  getmessage   1
#  pub          2
#  end          2
#  brace        2
#
#  [188 rows x 1 columns],
#            0
#  i         2
#  am        1
#  trying    1
#  to        4
#  retrieve  1
#  role      2
#  info      1
#  as        1
#  below     1
#  var       2
#  allroles  2
#  from      1
#  roles     4
#  in        1
#  context   1
#  aspnet    1
#  select    1
#  new       1
#  roleid    1
#  rolename  1
#  tolist    1
#  want      1
#  store     1
#  these     1
#  data      1
#  a         1
#  specific  1
#  class     1
#  type      2
#  or        1
#  list      1
#  lt        1
#  string    1
#  gt        1
#  not       1
#  object    1
#  of        1
#  like      1,
#              0
#  i           5
#  m           1
#  using       1
#  bootstraps  1
#  collapse    3
#  ...        ..
#  can         1
#  only        1
#  target      1
#  was         1
#  clicked     1
#
#  [64 rows x 1 columns],
#                  0
#  i               8
#  am              1
#  currently       1
#  studying        1
#  newick          3
#  ...            ..
#  size            2
#  childrenstring  8
#  childobject     5
#  else            1
#  return          1
#
#  [96 rows x 1 columns],
#             0
#  with       2
#  promisses  1
#  its        1
#  easy       1
#  becouse    1
#  ...       ..
#  how        1
#  make       1
#  code       1
#  work       1
#  thanks     1
#
#  [85 rows x 1 columns],
#             0
#  i         10
#  cannot     1
#  figure     1
#  this       5
#  out        1
#  ...       ..
#  addrect    3
#  setscene   1
#  show       1
#  exit       1
#  exec       1
#
#  [208 rows x 1 columns],
#                 0
#  i             13
#  get            1
#  a              1
#  message        1
#  when           1
#  try            1
#  to             2
#  run            1
#  the            5
#  program        1
#  why            2
#  segmentation   1
#  faultmy        1
#  code           1
#  include        1
#  lt             3
#  stdio          1
#  h              1
#  gt             3
#  void           1
#  sort           3
#  array          4
#  int            8
#  arr            8
#  s              4
#  main           1
#  arrx           3
#  for            1
#  r              5
#  printf         1
#  index          1
#  d              2
#  n              1
#  return         1
#  x             13
#  temp           6
#  while          2
#  if             2
#  think          3
#  that           2
#  problem        1
#  is             1
#  in             2
#  statement      1
#  what           1
#  do             1
#  you            2
#  does           1
#  it             1
#  happen         1
#  use            1
#  positive       1
#  way            1
#  with           1
#  pointer        1
#  thank          1,
#               0
#  i            3
#  am           1
#  new          1
#  to           5
#  aws          2
#  lambda       2
#  have         2
#  phantomjs    3
#  application  1
#  run          1
#  there        3
#  is           2
#  a            1
#  python       1
#  script       1
#  of           2
#  kb           1
#  and          2
#  binary       2
#  which        1
#  makes        1
#  the          2
#  whole        1
#  uploadable   1
#  zip          1
#  mb           1
#  upload       1
#  this         1
#  bunch        1
#  all          1
#  time         1
#  any          1
#  way          1
#  pushing      1
#  bin          1
#  folder       1
#  separately   1,
#             0
#  creating   1
#  a          8
#  custom     1
#  wordpress  1
#  theme      1
#  ...       ..
#  purple     1
#  size       1
#  any        1
#  advices    1
#  thanks     1
#
#  [151 rows x 1 columns],
#                0
#  i             2
#  want          1
#  to            1
#  count         1
#  a             1
#  specific      1
#  word          6
#  in            6
#  the           2
#  file          4
#  for           3
#  example       1
#  how           1
#  many          1
#  times         1
#  does          1
#  apple         2
#  appear        1
#  tried         1
#  this          1
#  usr           1
#  bin           1
#  env           1
#  pythonimport  1
#  re            1
#  logfile       2
#  open          1
#  log           1
#  r             1
#  wordcount     5
#  read          1
#  split         1
#  if            1
#  not           1
#  else          1
#  k             2
#  v             1
#  items         1
#  print         1
#  vby           1
#  replacing     1
#  with          1
#  but           1
#  it            1
#  still         1
#  counts        1
#  all           1
#  possible      1
#  words         1
#  my            1
#  any           1
#  advice        1
#  would         1
#  be            1
#  greatly       1
#  appreciated   1,
#             0
#  i          2
#  currently  2
#  have       1
#  this       2
#  code       1
#  ...       ..
#  item       2
#  split      1
#  if         1
#  lt         2
#  str        1
#
#  [107 rows x 1 columns],
#                      0
# ...
#  registerstartupscript  1
#  gettype                1
#  closepage              1
#  true                   1
#  can                    1
#  any                    1
#  one                    1
#  tell                   1
#  how                    1
#  do                     1,
#             0
#  i         67
#  m          2
#  creating   1
#  an         6
#  ai         1
#  ...       ..
#  scripts    1
#  cs         2
#  method     1
#  do         1
#  match      1
#
#  [408 rows x 1 columns],
#              0
#  i           8
#  understand  1
#  how         4
#  to          8
#  hash        1
#  ...        ..
#  t           1
#  will        1
#  accept      1
#  thanks      1
#  advance     1
#
#  [77 rows x 1 columns],
#               0
#  i            6
#  am           2
#  trying       1
#  to           5
#  find         1
#  ...         ..
#  alternative  1
#  solutions    1
#  type         1
#  plots        1
#  well         1
#
#  [96 rows x 1 columns],
#              0
#  i           5
#  m           1
#  not         3
#  understand  1
#  why         1
#  ...        ..
#  input       1
#  id          1
#  class       1
#  how         1
#  fix         1
#
#  [92 rows x 1 columns],
#            0
#  i         5
#  am        1
#  using     1
#  an        1
#  executor  1
#  ...      ..
#  what      1
#  observed  1
#  like      1
#  ms        2
#  where     1
#
#  [98 rows x 1 columns],
#              0
#  c           1
#  has         1
#  an          1
#  inbuilt     1
#  function    2
#  called      1
#  qsort       1
#  i           2
#  have        1
#  googled     1
#  how         1
#  to          1
#  use         1
#  this        1
#  in          3
#  program     1
#  but         1
#  cannot      1
#  fully       1
#  understand  1
#  it          2
#  can         1
#  somebody    1
#  please      1
#  explain     1
#  me          1
#  the         1
#  variables   1
#  involved    1
#  and         1
#  their       1
#  specific    1
#  purpose     1
#  simple      1
#  words       1
#  thanks      1,
#               0
#  i            4
#  want         1
#  to           6
#  export       1
#  my           2
#  ...         ..
#  exporting    1
#  databse      1
#  into         1
#  recoginized  1
#  sqlserver    1
#
#  [68 rows x 1 columns],
#            0
#  i         3
#  need      1
#  a         4
#  database  2
#  that      2
#  ...      ..
#  yield     1
#  faster    1
#  search    1
#  results   1
#  etc       1
#
#  [63 rows x 1 columns],
#                 0
#  i              5
#  have           2
#  an             1
#  app            2
#  where          1
#  ...           ..
#  cursoradapter  2
#  layout         1
#  row            1
#  list           1
#  setadapter     1
#
#  [88 rows x 1 columns],
#                     0
#  using              1
#  java               1
#  i                  2
#  m                  1
#  trying             1
#  to                 2
#  make               1
#  a                  1
#  simple             1
#  server             1
#  socket             1
#  that               1
#  is                 2
#  local              1
#  here               1
#  the                6
#  code               3
#  snippet            1
#  serversocket       3
#  new                1
#  doing              1
#  so                 1
#  gives              2
#  me                 2
#  error              3
#  cannot             1
#  assign             1
#  requested          1
#  addressscreenshot  1
#  of                 1
#  full               1
#  and                1
#  messagechanging    1
#  port               1
#  any                1
#  other              1
#  number             1
#  still              1
#  same               1
#  am                 1
#  running            1
#  through            1
#  an                 1
#  ide                1
#  intellij           1,
#                  0
#  new             1
#  to              2
#  rails           2
#  here            1
#  and             2
#  have            1
#  not             1
#  used            1
#  an              3
#  api             2
#  before          1
#  i               5
#  wanted          1
#  incorporate     1
#  this            2
#  into            1
#  my              1
#  app             1
#  https           1
#  github          1
#  com             1
#  codeforamerica  1
#  congress        1
#  where           1
#  would           1
#  put             2
#  the             1
#  code            1
#  found           1
#  under           1
#  set             1
#  up              1
#  ve              2
#  been            1
#  reading         1
#  it              1
#  should          2
#  go              1
#  in              3
#  environment     1
#  file            1
#  or              1
#  initializer     1
#  seen            1
#  a               1
#  lot             1
#  of              1
#  different       1
#  options         1
#  was             1
#  just            1
#  wondering       1
#  if              1
#  anyone          1
#  could           1
#  help            1
#  explain         1
#  using           1
#  s               1,
#                    0
#  i                 4
#  wanna             1
#  retrieve          3
#  parseuser         3
#  whn               1
#  parseobject       5
#  not               1
#  it                2
#  works             1
#  but               1
#  when              1
#  try               1
#  to                1
#  object            1
#  doesn             1
#  t                 1
#  work              1
#  what              1
#  do                2
#  parsequery        2
#  lt                3
#  gt                3
#  query             3
#  getquery          1
#  user              3
#  whereequalto      1
#  username          1
#  buddy             2
#  findinbackground  1
#  new               1
#  findcallback      1
#  override          1
#  public            1
#  void              1
#  done              1
#  list              1
#  puser             2
#  parseexception    1
#  e                 3
#  if                1
#  null              1
#  log               2
#  d                 2
#  retrieved         1
#  size              1
#  pu                2
#  textview          2
#  gendertext        3
#  findviewbyid      1
#  r                 1
#  id                1
#  settext           1
#  getstring         1
#  sex               1
#  else              1
#  error             1
#  getmessage        1,
#           0
#  cells    2
#  look     1
#  right    1
#  at       3
#  startup  1
#  ...     ..
#  default  1
#  return   1
#  down     1
#  back     1
#  top      1
#
#  [91 rows x 1 columns],
#                0
#  i             4
#  am            2
#  a             2
#  beginner      1
#  in            2
#  appcelerator  1
#  titanium      1
#  app           1
#  development   1
#  from          2
#  the           2
#  inspiration   1
#  of            1
#  this          2
#  link          1
#  trying        1
#  to            3
#  create        1
#  countdown     4
#  timer         1
#  be            1
#  work          1
#  tablerowview  1
#  as            1
#  each          1
#  row           6
#  have          1
#  its           1
#  own           1
#  time          1
#  set           1
#  and           5
#  customize     1
#  class         1
#  show          1
#  hours         1
#  seconds       1
#  like          1
#  sec           2
#  so            1
#  on            3
#  when          1
#  click         3
#  first         3
#  start         2
#  then          1
#  second        1
#  s             1
#  stop          2
#  again         1
#  last          1,
#                 0
#  i              6
#  was            5
#  wondering      2
#  if             4
#  it             2
#  possible       3
#  to             5
#  break          3
#  out            3
#  from           5
#  a              3
#  super          1
#  function       4
#  callback       3
#  simplified     1
#  my             4
#  code           2
#  be             1
#  more           1
#  readable       1
#  isclicked      3
#  var            1
#  userinputs     2
#  input          1
#  each           1
#  index          1
#  element        2
#  val            1
#  return         1
#  but            3
#  want           1
#  instinctively  1
#  wrote          1
#  this           1
#  quickly        1
#  realized       1
#  that           1
#  reasoning      1
#  wrong          1
#  returning      1
#  only           1
#  broke          1
#  the            4
#  current        1
#  iteration      1
#  of             1
#  so             1
#  basically      1
#  question       1
#  is             3
#  within         1
#  there          1
#  easy           1
#  fix            1
#  problem        1
#  above          1
#  even           1,
#             0
#  as         2
#  a          2
#  java       1
#  guy        1
#  trying     1
#  to         4
#  learn      1
#  c          1
#  i          2
#  m          1
#  little     1
#  confused   1
#  why        1
#  you        1
#  would      1
#  want       1
#  do         1
#  something  2
#  like       1
#  thisclass  1
#  question   6
#  private    2
#  string     5
#  ques       9
#  public     2
#  this       2
#  gt         2
#  versus     1
#  justclass  1
#  does       1
#  it         1
#  have       1
#  with       1
#  quot       2
#  inline     1
#  don        1
#  t          1
#  quite      1
#  know       1
#  what       1
#  that       1
#  means      1
#  either     1,
#                            0
#  i                         3
#  m                         2
#  attempting                1
#  to                        1
#  convert                   1
#  some                      1
#  existing                  1
#  c                         1
#  code                      2
#  into                      1
#  a                         1
#  portable                  1
#  class                     1
#  library                   1
#  project                   1
#  profile                   1
#  here                      1
#  is                        2
#  the                       5
#  stuck                     1
#  on                        1
#  system                    2
#  xml                       2
#  serialization             1
#  xmlanyattributeattribute  2
#  public                    1
#  xmlattribute              2
#  otherattributes           3
#  get                       1
#  return                    1
#  this                      2
#  set                       1
#  value                     1
#  what                      1
#  equivalent                1
#  of                        1
#  that                      2
#  in                        1
#  pcl                       1
#  land                      1
#  see                       1
#  xmlserializer             1
#  compiles                  1
#  fine                      1
#  exists                    1
#  but                       1
#  type                      1
#  does                      1
#  not                       1,
#              0
#  i           5
#  m           1
#  having      1
#  an          1
#  impossible  1
#  ...        ..
#  password    2
#  domain      1
#  enable      1
#  starttls    1
#  auto        1
#
#  [92 rows x 1 columns],
#             0
#  i         14
#  am         2
#  playing    1
#  with       6
#  google    11
#  ...       ..
#  thankful   1
#  if         1
#  guide      1
#  example    1
#  thanks     1
#
#  [127 rows x 1 columns],
#          0
#  i       9
#  have    1
#  a       7
#  data    3
#  set     2
#  ...    ..
#  amp     2
#  unique  1
#  false   1
#  next    1
#  end     1
#
#  [65 rows x 1 columns],
#                    0
#  i                 1
#  have              1
#  this              1
#  block             1
#  of                1
#  code              1
#  using             1
#  too               1
#  many              1
#  error             2
#  providers         1
#  assigned          1
#  to                3
#  each              1
#  textbox           1
#  is                3
#  there             1
#  any               1
#  other             1
#  way               2
#  or                1
#  shorter           1
#  particularly      1
#  set               1
#  one               1
#  provider          1
#  all               1
#  textboxes         1
#  if                1
#  txtholidayname    4
#  text              3
#  then              3
#  errorprovider     9
#  clear             6
#  seterror          3
#  holiday           3
#  name              1
#  required          2
#  focus             3
#  elseif            2
#  dtpholiday        4
#  value             2
#  lt                2
#  date              4
#  today             2
#  and               2
#  gt                2
#  must              1
#  be                1
#  greater           1
#  than              1
#  the               1
#  current           1
#  txtholidaysalary  3
#  salary            1,
#                 0
#  i              2
#  am             1
#  using          2
#  google         3
#  sheets         1
#  to             2
#  generate       1
#  image          3
#  urls           2
#  on             1
#  a              4
#  list           2
#  of             3
#  things         1
#  by             1
#  importxml      2
#  function       1
#  example        1
#  cell           3
#  flowercell     1
#  b              2
#  https          1
#  www            1
#  com            1
#  search         2
#  q              1
#  amp            4
#  source         1
#  lnms           1
#  tbm            1
#  isch           1
#  c              2
#  transpose      1
#  img            1
#  src            1
#  the            3
#  results        1
#  is             1
#  from           1
#  unfortunately  1
#  these          1
#  images         2
#  are            1
#  all            1
#  thumbnails     1
#  how            1
#  can            1
#  amend          1
#  above          1
#  formulae       1
#  obtain         1
#  bigger         1
#  sized          1,
#               0
#  i           10
#  am           3
#  new          1
#  to           7
#  python       2
#  ...         ..
#  further      1
#  research     1
#  greatly      1
#  appreciate   1
#  it           1
#
#  [85 rows x 1 columns],
#            0
#  i         5
#  send      2
#  a         2
#  base      1
#  encoded   1
#  ...      ..
#  mmax      1
#  input     1
#  vars      1
#  upload    1
#  filesize  1
#
#  [83 rows x 1 columns],
#            0
#  if        4
#  i         5
#  make      1
#  my        2
#  own       2
#  ...      ..
#  allow     1
#  adding    1
#  removing  1
#  thank     1
#  you       1
#
#  [103 rows x 1 columns],
#              0
#  actually    1
#  this        1
#  tread       1
#  is          5
#  continuing  1
#  ...        ..
#  lt          2
#  goups       1
#  arrays      1
#  sort        1
#  coingroups  1
#
#  [62 rows x 1 columns],
#                   0
#  in               1
#  the              2
#  following        1
#  example          1
#  test             4
#  that             3
#  v               18
#  function         3
#  was              3
#  called           3
#  fails            1
#  is               1
#  there            1
#  a                1
#  way              1
#  to               1
#  force            1
#  call             1
#  base             1
#  implementation   1
#  of               2
#  runfunction      5
#  through          1
#  an               1
#  instance         1
#  class            3
#  public           3
#  virtual          1
#  string           2
#  return           2
#  override         1
#  void             1
#  testcall         1
#  var              2
#  new              2
#  assert           2
#  istrue           2
#  thanks           1
#  for              1
#  looking          1
#  guys             1
#  and              1
#  gals             1,
#         0
#  i      3
#  want   1
#  to     6
#  give   1
#  my     1
#  ...   ..
#  just   1
#  note   1
#  using  1
#  scene  1
#  not    1
#
#  [70 rows x 1 columns],
#             0
#  i          6
#  d          1
#  like       1
#  to        12
#  know       1
#  ...       ..
#  however    1
#  hesitant   1
#  change     1
#  so         1
#  depends    1
#
#  [124 rows x 1 columns],
#              0
#  how         1
#  to          1
#  check       1
#  from        1
#  inside      1
#  the         3
#  view        1
#  if          1
#  there       1
#  are         1
#  any         1
#  modelstate  1
#  errors      1
#  for         1
#  specific    1
#  key         3
#  is          1
#  field       1
#  of          1
#  model       1,
#               0
#  in           5
#  other        1
#  words        1
#  what         2
#  technology   1
#  ...         ..
#  can          1
#  get          1
#  totally      1
#  appreciated  1
#  advance      1
#
#  [137 rows x 1 columns],
#          0
#  hallo   1
#  all     1
#  i       7
#  have    1
#  a       6
#  ...    ..
#  an      2
#  how     1
#  find    1
#  thanks  1
#  lot     1
#
#  [101 rows x 1 columns],
#              0
#  are         2
#  there       2
#  any         1
#  well        1
#  known       1
#  libraries   1
#  in          1
#  java        2
#  for         2
#  sparse      2
#  bit         1
#  vectors     1
#  and         1
#  guidelines  1
#  how         1
#  is          1
#  useful      1
#  to          1
#  use         1
#  them        1
#  vs          1
#  util        1
#  bitset      1,
#             0
#  i         15
#  know       1
#  this       2
#  question   1
#  gets       1
#  ...       ..
#  top        1
#  ff         2
#  medium     1
#  normal     1
#  hover      1
#
#  [167 rows x 1 columns],
#  ...]

# %%
total_freq = {}
for dictionnary in vocabulary['frequency']:
    for k,v in dictionnary.items():
        if k in total_freq:
            total_freq[k] += v
        else:
            total_freq[k] = v

# %%
freq_list = sorted(total_freq.items(), key=lambda x: x[1], reverse=True)
freq_list
# Out:
# [('the', 390535),
#  ('i', 319969),
#  ('to', 270151),
#  ('a', 224725),
#  ('gt', 181510),
#  ('lt', 166282),
#  ('is', 146774),
#  ('and', 133478),
#  ('in', 130809),
#  ('of', 110067),
#  ('this', 104488),
#  ('it', 101978),
#  ('that', 93186),
#  ('for', 78228),
#  ('have', 64961),
#  ('on', 55382),
#  ('if', 55381),
#  ('but', 54456),
#  ('with', 54242),
#  ('my', 53954),
#  ('be', 50259),
#  ('t', 47335),
#  ('can', 46627),
#  ('as', 46005),
#  ('not', 44674),
#  ('s', 41278),
#  ('an', 41045),
#  ('from', 40261),
#  ('m', 39968),
#  ('do', 37923),
#  ('or', 35695),
#  ('class', 35251),
#  ('id', 34181),
#  ('like', 33634),
#  ('using', 33510),
#  ('new', 33482),
#  ('code', 33151),
#  ('there', 32968),
#  ('so', 32694),
#  ('how', 32202),
#  ('what', 30897),
#  ('are', 30520),
#  ('c', 30400),
#  ('get', 30250),
#  ('when', 29920),
#  ('name', 29271),
#  ('string', 28933),
#  ('data', 28389),
#  ('at', 28120),
#  ('am', 28017),
#  ('file', 27801),
#  ('would', 27054),
#  ('any', 26920),
#  ('use', 25157),
#  ('you', 24168),
#  ('which', 24128),
#  ('want', 23856),
#  ('some', 23573),
#  ('all', 23349),
#  ('way', 23116),
#  ('quot', 22576),
#  ('value', 22201),
#  ('function', 21468),
#  ('public', 21285),
#  ('user', 20962),
#  ('one', 20823),
#  ('x', 20591),
#  ('type', 20115),
#  ('text', 20029),
#  ('int', 19537),
#  ('java', 19477),
#  ('return', 19255),
#  ('by', 19120),
#  ('d', 18638),
#  ('error', 18603),
#  ('will', 18236),
#  ('need', 17884),
#  ('div', 17830),
#  ('has', 16834),
#  ('e', 16732),
#  ('system', 16704),
#  ('amp', 16699),
#  ('application', 16633),
#  ('server', 16630),
#  ('me', 16495),
#  ('out', 16370),
#  ('just', 16350),
#  ('table', 16073),
#  ('then', 15736),
#  ('set', 15710),
#  ('know', 15283),
#  ('object', 15274),
#  ('page', 14949),
#  ('here', 14787),
#  ('ve', 14785),
#  ('where', 14354),
#  ('net', 14204),
#  ('only', 14191),
#  ('does', 14189),
#  ('list', 14186),
#  ('com', 13786),
#  ('method', 13706),
#  ('into', 13599),
#  ('no', 13539),
#  ('we', 13513),
#  ('problem', 13476),
#  ('should', 13356),
#  ('time', 13338),
#  ('other', 13224),
#  ('add', 13181),
#  ('b', 13121),
#  ('was', 13060),
#  ('work', 12866),
#  ('null', 12651),
#  ('http', 12585),
#  ('app', 12397),
#  ('something', 12222),
#  ('web', 12197),
#  ('void', 12178),
#  ('android', 12165),
#  ('html', 12031),
#  ('up', 11941),
#  ('php', 11717),
#  ('create', 11671),
#  ('database', 11640),
#  ('example', 11606),
#  ('test', 11559),
#  ('trying', 11334),
#  ('var', 11322),
#  ('form', 11231),
#  ('true', 10948),
#  ('same', 10926),
#  ('each', 10854),
#  ('select', 10832),
#  ('don', 10792),
#  ('now', 10761),
#  ('about', 10647),
#  ('following', 10468),
#  ('array', 10462),
#  ('also', 10375),
#  ('thanks', 10326),
#  ('first', 10282),
#  ('p', 10050),
#  ('make', 10043),
#  ('could', 10012),
#  ('line', 10006),
#  ('run', 10000),
#  ('find', 9882),
#  ('more', 9753),
#  ('view', 9682),
#  ('input', 9574),
#  ('f', 9565),
#  ('files', 9525),
#  ('sql', 9491),
#  ('script', 9410),
#  ('image', 9274),
#  ('n', 9251),
#  ('button', 9158),
#  ('self', 9085),
#  ('they', 8954),
#  ('question', 8916),
#  ('help', 8883),
#  ('project', 8882),
#  ('xml', 8820),
#  ('query', 8628),
#  ('windows', 8618),
#  ('them', 8506),
#  ('see', 8494),
#  ('end', 8471),
#  ('px', 8462),
#  ('url', 8452),
#  ('item', 8438),
#  ('key', 8365),
#  ('content', 8354),
#  ('number', 8227),
#  ('tried', 8204),
#  ('call', 8150),
#  ('works', 8129),
#  ('possible', 8103),
#  ('org', 8090),
#  ('else', 7997),
#  ('two', 7963),
#  ('anyone', 7918),
#  ('size', 7890),
#  ('however', 7854),
#  ('working', 7804),
#  ('main', 7788),
#  ('width', 7769),
#  ('asp', 7735),
#  ('used', 7728),
#  ('td', 7707),
#  ('doesn', 7662),
#  ('result', 7556),
#  ('these', 7541),
#  ('because', 7511),
#  ('false', 7509),
#  ('after', 7443),
#  ('h', 7436),
#  ('row', 7352),
#  ('r', 7307),
#  ('been', 7302),
#  ('private', 7286),
#  ('version', 7242),
#  ('date', 7224),
#  ('try', 7127),
#  ('import', 7078),
#  ('right', 7053),
#  ('update', 6930),
#  ('able', 6857),
#  ('control', 6824),
#  ('edit', 6812),
#  ('event', 6777),
#  ('different', 6777),
#  ('why', 6771),
#  ('path', 6767),
#  ('message', 6740),
#  ('static', 6713),
#  ('javascript', 6707),
#  ('values', 6691),
#  ('post', 6676),
#  ('request', 6668),
#  ('read', 6635),
#  ('write', 6622),
#  ('while', 6581),
#  ('users', 6560),
#  ('seems', 6554),
#  ('another', 6538),
#  ('case', 6525),
#  ('solution', 6459),
#  ('style', 6417),
#  ('change', 6250),
#  ('source', 6247),
#  ('without', 6211),
#  ('access', 6190),
#  ('start', 6170),
#  ('than', 6167),
#  ('client', 6167),
#  ('found', 6160),
#  ('index', 6140),
#  ('service', 6135),
#  ('its', 6121),
#  ('doing', 6115),
#  ('log', 6106),
#  ('best', 6070),
#  ('python', 6052),
#  ('property', 6028),
#  ('li', 6003),
#  ('column', 5993),
#  ('document', 5942),
#  ('exception', 5942),
#  ('title', 5937),
#  ('open', 5936),
#  ('display', 5922),
#  ('height', 5912),
#  ('y', 5879),
#  ('simple', 5866),
#  ('program', 5833),
#  ('click', 5769),
#  ('show', 5692),
#  ('db', 5615),
#  ('field', 5565),
#  ('looking', 5563),
#  ('window', 5562),
#  ('running', 5561),
#  ('default', 5545),
#  ('your', 5537),
#  ('very', 5510),
#  ('include', 5426),
#  ('model', 5406),
#  ('option', 5397),
#  ('through', 5395),
#  ('etc', 5369),
#  ('output', 5360),
#  ('good', 5348),
#  ('even', 5316),
#  ('link', 5280),
#  ('process', 5273),
#  ('before', 5252),
#  ('really', 5230),
#  ('build', 5227),
#  ('please', 5217),
#  ('color', 5201),
#  ('fine', 5181),
#  ('site', 5154),
#  ('g', 5135),
#  ('load', 5134),
#  ('being', 5123),
#  ('print', 5118),
#  ('still', 5110),
#  ('element', 5108),
#  ('lib', 5090),
#  ('order', 5073),
#  ('think', 5044),
#  ('library', 5013),
#  ('such', 4980),
#  ('thread', 4979),
#  ('jquery', 4969),
#  ('label', 4966),
#  ('length', 4963),
#  ('both', 4949),
#  ('current', 4946),
#  ('left', 4923),
#  ('many', 4888),
#  ('sure', 4879),
#  ('mysql', 4860),
#  ('foo', 4849),
#  ('v', 4838),
#  ('having', 4781),
#  ('back', 4768),
#  ('created', 4765),
#  ('js', 4748),
#  ('getting', 4717),
#  ('background', 4710),
#  ('css', 4643),
#  ('go', 4601),
#  ('better', 4587),
#  ('layout', 4578),
#  ('src', 4578),
#  ('check', 4570),
#  ('below', 4568),
#  ('count', 4542),
#  ('since', 4499),
#  ('point', 4497),
#  ('www', 4493),
#  ('action', 4491),
#  ('every', 4468),
#  ('well', 4434),
#  ('our', 4414),
#  ('information', 4381),
#  ('char', 4373),
#  ('over', 4360),
#  ('called', 4358),
#  ('j', 4348),
#  ('google', 4344),
#  ('api', 4310),
#  ('items', 4299),
#  ('command', 4294),
#  ('body', 4281),
#  ('done', 4243),
#  ('response', 4242),
#  ('between', 4214),
#  ('instead', 4212),
#  ('href', 4203),
#  ('put', 4170),
#  ('much', 4167),
#  ('currently', 4157),
#  ('objects', 4152),
#  ('top', 4152),
#  ('context', 4149),
#  ('instance', 4117),
#  ('parent', 4115),
#  ('search', 4087),
#  ('got', 4083),
#  ('const', 4070),
#  ('connection', 4065),
#  ('long', 4034),
#  ('their', 4020),
#  ('images', 4011),
#  ('console', 4010),
#  ('format', 4001),
#  ('variable', 3962),
#  ('let', 3961),
#  ('based', 3960),
#  ('session', 3947),
#  ('base', 3917),
#  ('password', 3901),
#  ('std', 3897),
#  ('o', 3887),
#  ('wrong', 3885),
#  ('bit', 3854),
#  ('last', 3853),
#  ('second', 3832),
#  ('email', 3824),
#  ('cannot', 3819),
#  ('above', 3803),
#  ('controller', 3803),
#  ('tr', 3788),
#  ('most', 3771),
#  ('already', 3763),
#  ('rows', 3761),
#  ('results', 3757),
#  ('visual', 3736),
#  ('issue', 3731),
#  ('part', 3722),
#  ('seem', 3707),
#  ('img', 3705),
#  ('position', 3668),
#  ('say', 3667),
#  ('header', 3640),
#  ('close', 3579),
#  ('map', 3567),
#  ('may', 3562),
#  ('insert', 3562),
#  ('looks', 3550),
#  ('font', 3545),
#  ('w', 3536),
#  ('classes', 3530),
#  ('thing', 3521),
#  ('span', 3518),
#  ('json', 3508),
#  ('idea', 3503),
#  ('studio', 3493),
#  ('within', 3479),
#  ('info', 3472),
#  ('reference', 3472),
#  ('memory', 3467),
#  ('methods', 3466),
#  ('node', 3458),
#  ('custom', 3456),
#  ('next', 3450),
#  ('directory', 3448),
#  ('echo', 3448),
#  ('inside', 3439),
#  ('framework', 3438),
#  ('re', 3436),
#  ('box', 3425),
#  ('local', 3425),
#  ('ruby', 3407),
#  ('tag', 3400),
#  ('send', 3397),
#  ('state', 3385),
#  ('address', 3367),
#  ('answer', 3358),
#  ('def', 3357),
#  ('had', 3353),
#  ('bar', 3352),
#  ('template', 3338),
#  ('ajax', 3336),
#  ('look', 3328),
#  ('things', 3318),
#  ('down', 3317),
#  ('single', 3312),
#  ('those', 3309),
#  ('returns', 3309),
#  ('multiple', 3309),
#  ('around', 3299),
#  ('specific', 3277),
#  ('l', 3276),
#  ('microsoft', 3272),
#  ('location', 3249),
#  ('ideas', 3244),
#  ('menu', 3220),
#  ('always', 3216),
#  ('contains', 3213),
#  ('anything', 3211),
#  ('going', 3210),
#  ('interface', 3200),
#  ('too', 3180),
#  ('login', 3161),
#  ('config', 3159),
#  ('support', 3152),
#  ('correct', 3150),
#  ('might', 3145),
#  ('ui', 3134),
#  ('dll', 3128),
#  ('save', 3114),
#  ('tables', 3113),
#  ('via', 3109),
#  ('catch', 3090),
#  ('store', 3083),
#  ('double', 3075),
#  ('added', 3069),
#  ('handle', 3056),
#  ('apache', 3054),
#  ('group', 3054),
#  ('none', 3053),
#  ('ie', 3049),
#  ('options', 3040),
#  ('given', 3039),
#  ('far', 3026),
#  ('someone', 3023),
#  ('own', 3020),
#  ('folder', 3007),
#  ('must', 2994),
#  ('understand', 2984),
#  ('u', 2982),
#  ('browser', 2964),
#  ('product', 2954),
#  ('take', 2947),
#  ('lot', 2938),
#  ('debug', 2931),
#  ('properties', 2918),
#  ('br', 2913),
#  ('delete', 2911),
#  ('columns', 2897),
#  ('note', 2887),
#  ('uses', 2884),
#  ('actually', 2883),
#  ('status', 2882),
#  ('username', 2878),
#  ('similar', 2874),
#  ('fields', 2871),
#  ('convert', 2870),
#  ('remove', 2863),
#  ('pass', 2846),
#  ('everything', 2832),
#  ('either', 2832),
#  ('stored', 2825),
#  ('internal', 2819),
#  ('missing', 2789),
#  ('match', 2788),
#  ('few', 2788),
#  ('loop', 2785),
#  ('root', 2772),
#  ('execute', 2764),
#  ('level', 2749),
#  ('float', 2739),
#  ('isn', 2732),
#  ('changes', 2720),
#  ('writing', 2710),
#  ('again', 2703),
#  ('k', 2701),
#  ('models', 2699),
#  ('os', 2693),
#  ('creating', 2690),
#  ('available', 2671),
#  ('website', 2666),
#  ('child', 2658),
#  ('home', 2656),
#  ('did', 2650),
#  ('copy', 2642),
#  ('once', 2636),
#  ('tostring', 2629),
#  ('replace', 2628),
#  ('needs', 2618),
#  ('elements', 2617),
#  ('screen', 2614),
#  ('side', 2607),
#  ('language', 2607),
#  ('sort', 2600),
#  ('errors', 2592),
#  ('module', 2570),
#  ('wondering', 2570),
#  ('byte', 2562),
#  ('machine', 2559),
#  ('join', 2552),
#  ('vs', 2537),
#  ('give', 2532),
#  ('functions', 2528),
#  ('appreciated', 2519),
#  ('implement', 2510),
#  ('block', 2508),
#  ('grid', 2504),
#  ('max', 2499),
#  ('reason', 2487),
#  ('eclipse', 2484),
#  ('val', 2479),
#  ('py', 2465),
#  ('gets', 2459),
#  ('keep', 2457),
#  ('override', 2452),
#  ('z', 2442),
#  ('controls', 2438),
#  ('projects', 2427),
#  ('task', 2424),
#  ('configuration', 2423),
#  ('core', 2414),
#  ('auto', 2410),
#  ('boost', 2408),
#  ('col', 2400),
#  ('though', 2399),
#  ('mvc', 2398),
#  ('nothing', 2397),
#  ('parameters', 2394),
#  ('target', 2379),
#  ('break', 2373),
#  ('allow', 2368),
#  ('integer', 2367),
#  ('advance', 2363),
#  ('several', 2357),
#  ('required', 2353),
#  ('forms', 2348),
#  ('parameter', 2347),
#  ('empty', 2344),
#  ('figure', 2341),
#  ('standard', 2336),
#  ('connect', 2332),
#  ('final', 2326),
#  ('pages', 2325),
#  ('rather', 2323),
#  ('easy', 2310),
#  ('utf', 2299),
#  ('made', 2297),
#  ('str', 2273),
#  ('container', 2273),
#  ('init', 2272),
#  ('selected', 2272),
#  ('security', 2271),
#  ('description', 2270),
#  ('written', 2261),
#  ('off', 2260),
#  ('rails', 2257),
#  ('ok', 2252),
#  ('border', 2248),
#  ('https', 2247),
#  ('activity', 2245),
#  ('obj', 2243),
#  ('attribute', 2238),
#  ('ul', 2236),
#  ('tell', 2234),
#  ('statement', 2230),
#  ('head', 2229),
#  ('filter', 2226),
#  ('sub', 2223),
#  ('stuff', 2212),
#  ('kind', 2204),
#  ('lines', 2201),
#  ('println', 2196),
#  ('place', 2191),
#  ('non', 2187),
#  ('settings', 2177),
#  ('people', 2174),
#  ('performance', 2173),
#  ('large', 2163),
#  ('lang', 2158),
#  ('testing', 2156),
#  ('alert', 2154),
#  ('textbox', 2153),
#  ('approach', 2147),
#  ('ms', 2144),
#  ('under', 2141),
#  ('datetime', 2138),
#  ('setting', 2135),
#  ('maybe', 2132),
#  ('little', 2124),
#  ('submit', 2124),
#  ('category', 2122),
#  ('times', 2120),
#  ('compile', 2116),
#  ('calls', 2113),
#  ('th', 2113),
#  ('param', 2109),
#  ('structure', 2107),
#  ('margin', 2106),
#  ('implementation', 2089),
#  ('basically', 2085),
#  ('generate', 2082),
#  ('generated', 2081),
#  ('linux', 2077),
#  ('never', 2074),
#  ('tests', 2070),
#  ('thought', 2068),
#  ('record', 2052),
#  ('filename', 2051),
#  ('release', 2050),
#  ('small', 2050),
#  ('tab', 2045),
#  ('full', 2042),
#  ('types', 2042),
#  ('domain', 2041),
#  ('vector', 2038),
#  ('failed', 2035),
#  ('were', 2033),
#  ('adding', 2029),
#  ('range', 2026),
#  ('install', 2019),
#  ('django', 2018),
#  ('problems', 2018),
#  ('defined', 2016),
#  ('thank', 2013),
#  ('applications', 2006),
#  ('suggestions', 2005),
#  ('usr', 2005),
#  ('boolean', 2000),
#  ('mode', 1999),
#  ('yes', 1999),
#  ('development', 1996),
#  ('bin', 1995),
#  ('basic', 1994),
#  ('foreach', 1989),
#  ('changed', 1987),
#  ('args', 1984),
#  ('unit', 1984),
#  ('tools', 1983),
#  ('word', 1980),
#  ('sample', 1976),
#  ('require', 1973),
#  ('calling', 1973),
#  ('center', 1961),
#  ('ll', 1959),
#  ('binding', 1959),
#  ('frame', 1957),
#  ('bool', 1953),
#  ('append', 1953),
#  ('enter', 1952),
#  ('cell', 1951),
#  ('entity', 1949),
#  ('shows', 1946),
#  ('entry', 1941),
#  ('temp', 1939),
#  ('old', 1934),
#  ('collection', 1927),
#  ('correctly', 1925),
#  ('active', 1925),
#  ('plugin', 1921),
#  ('parse', 1917),
#  ('assembly', 1917),
#  ('cache', 1904),
#  ('admin', 1901),
#  ('tags', 1900),
#  ('linq', 1895),
#  ('dialog', 1894),
#  ('rb', 1891),
#  ('stack', 1890),
#  ('environment', 1889),
#  ('num', 1888),
#  ('clear', 1884),
#  ('tool', 1881),
#  ('component', 1879),
#  ('installed', 1877),
#  ('nbsp', 1874),
#  ('common', 1870),
#  ('move', 1869),
#  ('names', 1869),
#  ('stream', 1868),
#  ('setup', 1864),
#  ('exe', 1854),
#  ('define', 1851),
#  ('person', 1847),
#  ('success', 1845),
#  ('design', 1845),
#  ('svn', 1844),
#  ('variables', 1841),
#  ('aspx', 1841),
#  ('namespace', 1841),
#  ('iphone', 1837),
#  ('gems', 1836),
#  ('day', 1829),
#  ('making', 1821),
#  ('us', 1821),
#  ('seen', 1807),
#  ('pretty', 1806),
#  ('didn', 1802),
#  ('certain', 1802),
#  ('services', 1801),
#  ('events', 1801),
#  ('fix', 1799),
#  ('makes', 1796),
#  ('total', 1796),
#  ('simply', 1794),
#  ('xmlns', 1791),
#  ('quite', 1790),
#  ('section', 1788),
#  ('come', 1784),
#  ('numbers', 1784),
#  ('png', 1779),
#  ('until', 1774),
#  ('expected', 1771),
#  ('itself', 1770),
#  ('resources', 1768),
#  ('buffer', 1765),
#  ('protected', 1765),
#  ('account', 1763),
#  ('job', 1760),
#  ('port', 1759),
#  ('win', 1759),
#  ('strings', 1759),
#  ('handler', 1758),
#  ('real', 1758),
#  ('package', 1758),
#  ('whether', 1754),
#  ('particular', 1746),
#  ('excel', 1744),
#  ('original', 1742),
#  ('valid', 1739),
#  ('device', 1738),
#  ('per', 1737),
#  ('padding', 1733),
#  ('great', 1728),
#  ('details', 1720),
#  ('exists', 1717),
#  ('txt', 1712),
#  ('checked', 1712),
#  ('takes', 1711),
#  ('built', 1709),
#  ('messages', 1705),
#  ('resource', 1701),
#  ('intent', 1697),
#  ('customer', 1687),
#  ('mean', 1683),
#  ('pattern', 1683),
#  ('bottom', 1680),
#  ('dim', 1680),
#  ('reading', 1678),
#  ('socket', 1678),
#  ('company', 1676),
#  ('separate', 1673),
#  ('regex', 1668),
#  ('difference', 1668),
#  ('loaded', 1666),
#  ('provide', 1655),
#  ('jar', 1655),
#  ('course', 1653),
#  ('documentation', 1649),
#  ('hidden', 1647),
#  ('io', 1644),
#  ('sun', 1644),
#  ('report', 1642),
#  ('related', 1637),
#  ('random', 1634),
#  ('characters', 1626),
#  ('primary', 1626),
#  ('whole', 1626),
#  ('started', 1625),
#  ('yet', 1624),
#  ('varchar', 1624),
#  ('compiler', 1621),
#  ('contents', 1620),
#  ('existing', 1619),
#  ('oracle', 1618),
#  ('sender', 1614),
#  ('thinking', 1614),
#  ('questions', 1613),
#  ('encoding', 1612),
#  ('actual', 1610),
#  ('gives', 1609),
#  ('automatically', 1608),
#  ('happens', 1601),
#  ('bind', 1598),
#  ('records', 1598),
#  ('upload', 1597),
#  ('enough', 1595),
#  ('runtime', 1594),
#  ('schema', 1593),
#  ('q', 1593),
#  ('jpg', 1590),
#  ('syntax', 1587),
#  ('step', 1584),
#  ('character', 1580),
#  ('host', 1577),
#  ('pointer', 1574),
#  ('amount', 1572),
#  ('views', 1571),
#  ('super', 1571),
#  ('expression', 1567),
#  ('three', 1566),
#  ('probably', 1565),
#  ('who', 1561),
#  ('render', 1561),
#  ('stop', 1561),
#  ('unknown', 1550),
#  ('space', 1546),
#  ('extends', 1546),
#  ('virtual', 1546),
#  ('struct', 1539),
#  ('avoid', 1537),
#  ('directly', 1537),
#  ('free', 1525),
#  ('min', 1524),
#  ('returned', 1524),
#  ('localhost', 1518),
#  ('attributes', 1517),
#  ('validation', 1509),
#  ('functionality', 1508),
#  ('least', 1503),
#  ('firefox', 1502),
#  ('fill', 1499),
#  ('constructor', 1498),
#  ('price', 1494),
#  ('warning', 1492),
#  ('solve', 1491),
#  ('examples', 1489),
#  ('wrap', 1488),
#  ('vb', 1487),
#  ('invoke', 1487),
#  ('printf', 1486),
#  ('libraries', 1485),
#  ('hello', 1483),
#  ('hibernate', 1483),
#  ('updated', 1482),
#  ('means', 1480),
#  ('icon', 1479),
#  ('won', 1477),
#  ('runat', 1476),
#  ('external', 1473),
#  ('panel', 1471),
#  ('loading', 1467),
#  ('video', 1460),
#  ('normal', 1454),
#  ('properly', 1451),
#  ('developer', 1451),
#  ('checkbox', 1450),
#  ('exactly', 1448),
#  ('points', 1448),
#  ('year', 1448),
#  ('appears', 1447),
#  ('throw', 1446),
#  ('onclick', 1441),
#  ('xsl', 1441),
#  ('issues', 1440),
#  ('hash', 1440),
#  ('except', 1439),
#  ('runs', 1428),
#  ('cursor', 1428),
#  ('nil', 1425),
#  ('global', 1423),
#  ('generic', 1422),
#  ('links', 1413),
#  ('procedure', 1408),
#  ('spring', 1404),
#  ('scope', 1404),
#  ('bad', 1404),
#  ('switch', 1401),
#  ('seconds', 1400),
#  ('goes', 1400),
#  ('building', 1398),
#  ('shared', 1398),
#  ('tree', 1397),
#  ('ex', 1394),
#  ('download', 1393),
#  ('bytes', 1387),
#  ('threads', 1386),
#  ('achieve', 1386),
#  ('game', 1385),
#  ('comment', 1382),
#  ('network', 1377),
#  ('exist', 1376),
#  ('wpf', 1376),
#  ('util', 1375),
#  ('queries', 1370),
#  ('programming', 1366),
#  ('align', 1365),
#  ('pdf', 1365),
#  ('keys', 1365),
#  ('guess', 1364),
#  ('native', 1360),
#  ('attr', 1356),
#  ('unique', 1355),
#  ('member', 1354),
#  ('en', 1349),
#  ('nice', 1346),
#  ('cout', 1346),
#  ('ip', 1345),
#  ('software', 1341),
#  ('displayed', 1341),
#  ('platform', 1339),
#  ('contact', 1338),
#  ('remote', 1335),
#  ('mail', 1335),
#  ('widget', 1333),
#  ('says', 1332),
#  ('split', 1331),
#  ('needed', 1329),
#  ('invalid', 1327),
#  ('begin', 1327),
#  ('contain', 1320),
#  ('manually', 1318),
#  ('exit', 1317),
#  ('during', 1316),
#  ('getelementbyid', 1315),
#  ('complete', 1313),
#  ('experience', 1312),
#  ('haven', 1311),
#  ('res', 1311),
#  ('extension', 1307),
#  ('processing', 1305),
#  ('answers', 1305),
#  ('big', 1304),
#  ('later', 1303),
#  ('previous', 1298),
#  ('gl', 1294),
#  ('worked', 1292),
#  ('feature', 1290),
#  ('anybody', 1290),
#  ('iis', 1290),
#  ('comes', 1288),
#  ('sp', 1286),
#  ('sum', 1282),
#  ('ways', 1281),
#  ('fails', 1280),
#  ('drop', 1280),
#  ('general', 1274),
#  ('dynamic', 1274),
#  ('across', 1273),
#  ('phone', 1273),
#  ('various', 1272),
#  ('sent', 1271),
#  ('dir', 1271),
#  ('words', 1268),
#  ('buttons', 1267),
#  ('products', 1265),
#  ('sometimes', 1263),
#  ('msg', 1262),
#  ('wanted', 1261),
#  ('less', 1258),
#  ('callback', 1254),
#  ('logic', 1253),
#  ('visible', 1252),
#  ('explain', 1244),
#  ('behavior', 1243),
#  ('hide', 1241),
#  ('appear', 1239),
#  ('passed', 1237),
#  ('comments', 1235),
#  ('starting', 1232),
#  ('layer', 1232),
#  ('repository', 1231),
#  ('red', 1230),
#  ('push', 1229),
#  ('limit', 1223),
#  ...]

# %%
idx, values = zip(*freq_list)
frequencies = pd.Series(values, idx)
frequencies.describe()
# Out:
# count    210060.000000
# mean         49.216457
# std        1744.789125
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max      390535.000000
# dtype: float64

# %%
top = frequencies.head(100)
top.plot(kind='bar', figsize=(20, 10))
plt.ylabel('Frequency')
plt.show()
top.describe()
# Out:
# count       100.000000
# mean      48083.360000
# std       62731.323721
# min       14186.000000
# 25%       18511.250000
# 50%       27909.000000
# 75%       42127.000000
# max      390535.000000
# dtype: float64

# %%
knee = KneeLocator([i for i,_ in enumerate(top.index.values)], top.values, curve='convex', direction='decreasing')
knee.plot_knee()
knee.knee
# Out:
# 15

# %%
frequencies.iloc[:knee.knee+1]
# Out:
# the        390535
# i          319969
# to         270151
# a          224725
# gt         181510
#             ...
# while        6581
# users        6560
# seems        6554
# another      6538
# case         6525
# Length: 228, dtype: int64

# %% [markdown]
# # Création d'une liste de stopwords

# %%
en_stopwords = nltk.corpus.stopwords.words('english')
to_drop = frequencies.index.intersection(en_stopwords)
to_drop
# Out:
# Index(['the', 'i', 'to', 'a', 'is', 'and', 'in', 'of', 'this', 'it',
#        ...
#        'himself', 'whom', 'yours', 'ain', 'mustn', 'herself', 'shan', 'needn',
#        'hers', 'yourselves'],
#       dtype='object', length=152)

# %%
len(en_stopwords)
# Out:
# 179

# %%
freq_wo_stop = frequencies.drop(to_drop)
freq_wo_stop.head(100).plot(kind='bar', figsize=(20,10))
plt.title('Top 100')
plt.show()
freq_wo_stop.plot(figsize=(20,10))
plt.title('Tous le dictionnaire')
plt.show()
freq_wo_stop.describe()
# Out:
# count    209908.000000
# mean         30.782562
# std         690.654022
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max      181510.000000
# dtype: float64

# %%
knee = KneeLocator([i for i,_ in enumerate(freq_wo_stop.index.values)], freq_wo_stop.values, curve='convex', direction='decreasing')
knee.plot_knee()
knee.knee
# Out:
# 227

# %%
sw = freq_wo_stop[:knee.knee+1].index.tolist() + en_stopwords
sw
# Out:
# ['gt',
#  'lt',
#  'class',
#  'id',
#  'like',
#  'using',
#  'new',
#  'code',
#  'c',
#  'get',
#  'name',
#  'string',
#  'data',
#  'file',
#  'would',
#  'use',
#  'want',
#  'way',
#  'quot',
#  'value',
#  'function',
#  'public',
#  'user',
#  'one',
#  'x',
#  'type',
#  'text',
#  'int',
#  'java',
#  'return',
#  'error',
#  'need',
#  'div',
#  'e',
#  'system',
#  'amp',
#  'application',
#  'server',
#  'table',
#  'set',
#  'know',
#  'object',
#  'page',
#  'net',
#  'list',
#  'com',
#  'method',
#  'problem',
#  'time',
#  'add',
#  'b',
#  'work',
#  'null',
#  'http',
#  'app',
#  'something',
#  'web',
#  'void',
#  'android',
#  'html',
#  'php',
#  'create',
#  'database',
#  'example',
#  'test',
#  'trying',
#  'var',
#  'form',
#  'true',
#  'select',
#  'following',
#  'array',
#  'also',
#  'thanks',
#  'first',
#  'p',
#  'make',
#  'could',
#  'line',
#  'run',
#  'find',
#  'view',
#  'input',
#  'f',
#  'files',
#  'sql',
#  'script',
#  'image',
#  'n',
#  'button',
#  'self',
#  'question',
#  'help',
#  'project',
#  'xml',
#  'query',
#  'windows',
#  'see',
#  'end',
#  'px',
#  'url',
#  'item',
#  'key',
#  'content',
#  'number',
#  'tried',
#  'call',
#  'works',
#  'possible',
#  'org',
#  'else',
#  'two',
#  'anyone',
#  'size',
#  'however',
#  'working',
#  'main',
#  'width',
#  'asp',
#  'used',
#  'td',
#  'result',
#  'false',
#  'h',
#  'row',
#  'r',
#  'private',
#  'version',
#  'date',
#  'try',
#  'import',
#  'right',
#  'update',
#  'able',
#  'control',
#  'edit',
#  'event',
#  'different',
#  'path',
#  'message',
#  'static',
#  'javascript',
#  'values',
#  'post',
#  'request',
#  'read',
#  'write',
#  'users',
#  'seems',
#  'another',
#  'case',
#  'solution',
#  'style',
#  'change',
#  'source',
#  'without',
#  'access',
#  'start',
#  'client',
#  'found',
#  'index',
#  'service',
#  'log',
#  'best',
#  'python',
#  'property',
#  'li',
#  'column',
#  'document',
#  'exception',
#  'title',
#  'open',
#  'display',
#  'height',
#  'simple',
#  'program',
#  'click',
#  'show',
#  'db',
#  'field',
#  'looking',
#  'window',
#  'running',
#  'default',
#  'include',
#  'model',
#  'option',
#  'etc',
#  'output',
#  'good',
#  'even',
#  'link',
#  'process',
#  'really',
#  'build',
#  'please',
#  'color',
#  'fine',
#  'site',
#  'g',
#  'load',
#  'print',
#  'still',
#  'element',
#  'lib',
#  'order',
#  'think',
#  'library',
#  'thread',
#  'jquery',
#  'label',
#  'length',
#  'current',
#  'left',
#  'many',
#  'sure',
#  'mysql',
#  'foo',
#  'v',
#  'back',
#  'created',
#  'js',
#  'getting',
#  'background',
#  'css',
#  'go',
#  'better',
#  'layout',
#  'i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# # Recalcul de la taille par post sans stopwords

# %%
normalized_tokens = posts.str.lower().map(lambda x: [token for token in tokenizer.tokenize(x) if not token in sw])
normalized_tokens
# Out:
# 0        [uiimageview, already, later, second, uiimagev...
# 2        [requirements, againstabout, people, allow, cl...
# 4        [gem, inside, rake, task, parse, contents, dum...
# 5        [includes, nested, primary, links, sub, menu, ...
# 7        [done, google, searching, custom, django, simi...
#                                ...
# 99706    [rid, std, vector, boost, ptr, vector, remove,...
# 99707       [singleton, factory, domains, factory, around]
# 99708    [wondering, keep, resharper, removing, directi...
# 99709    [started, documents, developing, apps, iphone,...
# 99710    [area, dots, distributed, area, detect, cluste...
# Name: Body, Length: 75481, dtype: object

# %%
norm_posts_size = normalized_tokens.map(len)
norm_posts_size.plot.hist(bins=np.arange(0, 200, 20))
plt.xlabel('Nombre de mots par post')
plt.axvline(x=norm_posts_size.quantile(), color="red", linestyle="--")
plt.show()
norm_posts_size.describe()
# Out:
# count    75481.000000
# mean        49.815914
# std         70.309094
# min          0.000000
# 25%         17.000000
# 50%         32.000000
# 75%         58.000000
# max       2730.000000
# Name: Body, dtype: float64

# %% [markdown]
# # Lemmatisation

# %%
wnl = WordNetLemmatizer()
lem_tokens = normalized_tokens.map(lambda x: [wnl.lemmatize(w) for w in x])
lem_tokens
# Out:
# 0        [uiimageview, already, later, second, uiimagev...
# 2        [requirement, againstabout, people, allow, clo...
# 4        [gem, inside, rake, task, parse, content, dump...
# 5        [includes, nested, primary, link, sub, menu, i...
# 7        [done, google, searching, custom, django, simi...
#                                ...
# 99706    [rid, std, vector, boost, ptr, vector, remove,...
# 99707        [singleton, factory, domain, factory, around]
# 99708    [wondering, keep, resharper, removing, directi...
# 99709    [started, document, developing, apps, iphone, ...
# 99710    [area, dot, distributed, area, detect, cluster...
# Name: Body, Length: 75481, dtype: object

# %%
lem_posts_unique_size = lem_tokens.map(lambda x: len(np.unique(x)))
lem_posts_unique_size.plot.hist(bins=np.arange(0,200,20))
plt.axvline(x=lem_posts_unique_size.quantile(), color="red", linestyle="--")
plt.xlabel("Nombre de lemmes par post")
plt.show()
lem_posts_unique_size.describe()
# Out:
# count    75481.000000
# mean        30.777812
# std         26.299124
# min          0.000000
# 25%         14.000000
# 50%         24.000000
# 75%         39.000000
# max        419.000000
# Name: Body, dtype: float64

# %% [markdown]
# # Merge

# %%
dataset['Body'] = lem_tokens
dataset.reset_index(inplace=True, drop=True)
dataset
# Out:
#                                                     Body  \
# 0      [uiimageview, already, later, second, uiimagev...
# 1      [requirement, againstabout, people, allow, clo...
# 2      [gem, inside, rake, task, parse, content, dump...
# 3      [includes, nested, primary, link, sub, menu, i...
# 4      [done, google, searching, custom, django, simi...
# ...                                                  ...
# 75476  [rid, std, vector, boost, ptr, vector, remove,...
# 75477      [singleton, factory, domain, factory, around]
# 75478  [wondering, keep, resharper, removing, directi...
# 75479  [started, document, developing, apps, iphone, ...
# 75480  [area, dot, distributed, area, detect, cluster...
#
#                            Tags
# 0                      [iphone]
# 1                [c#, winforms]
# 2                   [ruby, xml]
# 3                         [php]
# 4         [python, sql, django]
# ...                         ...
# 75476                     [c++]
# 75477                    [java]
# 75478  [c#, visual-studio-2008]
# 75479                  [iphone]
# 75480               [algorithm]
#
# [75481 rows x 2 columns]

# %%
body_content = [' '.join(words) for words in dataset['Body'].values]
dataset['Body'] = body_content
dataset.drop(dataset[dataset['Body'] == ''].index, inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75460 entries, 0 to 75480
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Body    75460 non-null  object
#  1   Tags    75460 non-null  object
# dtypes: object(2)
# memory usage: 1.7+ MB

# %%
dataset.to_csv('./cleaned_dataset.csv', index=False)
